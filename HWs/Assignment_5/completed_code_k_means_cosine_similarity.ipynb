# %%
#Sergiu Buciumas
####Hands-on Exercise on Natural Language Processing Pipeline
##This hands-on exercise is to practice what we learned on natural language processing 
##and vector space model of documents (blogs).  

###Please write Python code to do the following
###1.	Retrieve blogs from the following URL: ‘http://feeds.feedburner.com/oreilly/radar/atom’
###2.	Please complete one of the following exercises;
###Option1:  build a search engine on retrieved blogs.  The search engine receives a user’s query (one term or multiple terms)
###and ranks all the blog entries in the descending orders of relevancy to the user’s query.  
####The measure of relevancy is calculated by cosine similarity as we discussed in class
##Option2:  Conduct K-means clustering on all retrieved blogs based on the cosine similarity of blog entries. 
###Show all blogs that belong to each cluster.  Each blog will be represented by its automatically generated summary.

# %%
import io, json

def save_json(filename, data):
    with io.open('{0}.json'.format(filename), 
                 'w', encoding='utf-8') as f:
        f.write(json.dumps(data, ensure_ascii=False))

def load_json(filename):
    with io.open('{0}.json'.format(filename), 
                 encoding='utf-8') as f:
        return json.load(f)

# %%
import json
import feedparser
from bs4 import BeautifulSoup
from nltk import clean_html
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy
from nltk.cluster import KMeansClusterer, GAAClusterer, cosine_distance
import nltk.corpus
import nltk.stem

FEED_URL = 'http://feeds.feedburner.com/oreilly/radar/atom'

def cleanHtml(html):
    soup = BeautifulSoup(html,"lxml")
    return soup.get_text()

fp = feedparser.parse(FEED_URL)

print ("Fetched %s entries from '%s'" % (len(fp.entries[0].title), fp.feed.title))
blog_posts = []

for e in fp.entries:
    blog_posts.append({'title': e.title, 'content'
                      : cleanHtml(e.content[0].value)}) ##extracted the title of the blog and the content only, no link.

print (blog_posts[0])

save_json('blog',blog_posts)
# Out:
# Fetched 77 entries from 'All - O'Reilly Media'
# {'content': 'The O’Reilly Bots Podcast: How bots are transforming the way companies interact with their customers.Customer service is a key application for bots—one of the first that we think of when we imagine a world full of AI-enabled conversational interfaces. In this episode of the O’Reilly Bots podcast, Pete Skomoroch and I talk with the founders of two companies that have developed bots to help consumers and companies talk to each other.Continue reading Michael Schneider, Rachel Law, and Alyx Baldwin on customer service with bots.', 'title': 'Michael Schneider, Rachel Law, and Alyx Baldwin on customer service with bots'}

# %%
import json
import nltk

# Download nltk packages used in this example
nltk.download('stopwords')


blog_data = load_json('blog')

# Customize your list of stopwords as needed. Here, we add common
# punctuation and contraction artifacts.

stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    ]
counter = 0
master_list = []
for post in blog_data:
    sentences = nltk.tokenize.sent_tokenize(post['content']) #will be used in k-means
    #print(sentences)
    words = [w.lower() for sentence in sentences for w in # this ones will use in k-means
             nltk.tokenize.word_tokenize(sentence) if w[0] not in stop_words][:60]
    print(words)
    master_list.append(words)
    print(master_list)

    fdist = nltk.FreqDist(words) #will be used in k-means for creating the vector

    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once

    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = [w for w in fdist.items() if w[0]
                                    not in stop_words][:25]
    total_corpus = [x[0] for x in top_10_words_sans_stop_words]
    counter += 1
    print ('====|=======|=========|=======|===========|=======|=====')
    print("Blog number:", counter)
    print ('________________________________________________________')
    print(sentences)
    print ('========================================================')
    print("len of each list of words", len(words))
    print(words)
    print ('````````````````````````````````````````````````````````')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sbuciuma/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 1
# ________________________________________________________
# ['The O’Reilly Bots Podcast: How bots are transforming the way companies interact with their customers.Customer service is a key application for bots—one of the first that we think of when we imagine a world full of AI-enabled conversational interfaces.', 'In this episode of the O’Reilly Bots podcast, Pete Skomoroch and I talk with the founders of two companies that have developed bots to help consumers and companies talk to each other.Continue reading Michael Schneider, Rachel Law, and Alyx Baldwin on customer service with bots.']
# ========================================================
# len of each list of words 48
# ['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']
# ````````````````````````````````````````````````````````
# ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 2
# ________________________________________________________
# ["The O'Reilly Radar Podcast: Prediction algorithms, cognitive biases, and how our brains come online.On this week's episode, I chat with Sam Wang, professor of neuroscience and molecular biology at Princeton.", 'Wang is also a co-founder of the Princeton Election Consortium, a site focused on analyzing and predicting U.S. national elections.', "We talk about the site's prediction algorithm and this crazy election cycle, and the role neuroscience may have played.", 'We also talk about the current research Wang and his team are working on, the U.S.', 'BRAIN Initiative, and the powerful role governments play in academic research.Continue reading Sam Wang on predicting the election, finding truth in mass media, and a new role for the cerebellum.']
# ========================================================
# len of each list of words 60
# ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']
# ````````````````````````````````````````````````````````
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 3
# ________________________________________________________
# ['The O’Reilly Data Show Podcast: Christopher Nguyen on the early days of Apache Spark, deep learning for time-series and transactional data, innovation in China, and AI.In this episode of the O’Reilly Data Show, I spoke with Christopher Nguyen, CEO and co-founder of Arimo.', 'Nguyen and Arimo were among the first adopters and proponents of Apache Spark, Alluxio, and other open source technologies.', 'Most recently, Arimo’s suite of analytic products has relied on deep learning to address a range of business problems.Continue reading Why businesses should pay attention to deep learning.']
# ========================================================
# len of each list of words 48
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']
# ````````````````````````````````````````````````````````
# ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 4
# ________________________________________________________
# ["Kid Privacy, Chinese Creation, Reality Rocks, and Chaos Monkey 2\n\nDigital Defenders -- free, CC-licensed kids' booklet about privacy.", "(via Cory Doctorow)\n\nNews: Ideas Aren't Intrinsically Valuable -- executed ideas can be valuable, and Chinese hardware makers can execute faster than American ones.", 'This shows up as Kickstarter products show up for sale in Shenzhen before the Kickstarter closes.', '(via BoingBoing)\n\nThe World is Getting Better and Nobody Knows It --  In Britain, only 10% of people thought that world poverty had decreased in the past 30 years.', 'More than half thought it had increased.', 'In the United States, only 5% answered (correctly) that world poverty had been almost halved in the last 20 years: 66% thought it had almost doubled.', "Chaos Monkey 2.0 -- it's a sign of the times that a complex and useful piece of software in today's world is one which randomly turns off services.", 'Continue reading Four short links: 20 October 2016.']
# ========================================================
# len of each list of words 60
# ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']
# ````````````````````````````````````````````````````````
# ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 5
# ________________________________________________________
# ['If we let machines put us out of work, it will be because of a failure of imagination and a lack of will to make a better future.', "(Full text, video, and slides from Tim O'Reilly's talk at the White House Frontiers Conference.", ')I had the honor to be one of the warmup acts for President Obama at the White House Frontiers Conference at Carnegie Mellon University in Pittsburgh.', 'Here is the prepared text and slides from the talk I delivered there.', 'As you’ll see if you watch the video, what I ended up saying isn’t exactly what I had written out in advance, but it is reasonably close.', 'Hearing that Bob Dylan just won the Nobel Prize for Literature, how could I not begin this talk with his famous line, “Something is happening here, but you don’t know what it is, do you, Mr. Jones?” The future is full of amazing things.', 'On my way here, I spoke out loud to a $200 device in my kitchen, and asked it to call a Lyft to take me to the airport.', 'And in a few years, that car might well be driving itself.', 'Someone seeing this for the first time would have every excuse to say “WTF?” That of course is an expression of surprise and delight that stands for What’s the Future?', 'But many people are reading the news about artificial intelligence and are feeling a profound sense of unease.', 'They are also asking themselves “WTF?', 'What’s the Future?”, but in a very different tone of voice.', 'We heard recently from researchers at Oxford University that up to 47% of human tasks, including many white collar jobs, could be eliminated by automation within the next 20 years.', 'Figure 2.', 'New study shows nearly half of U.S. jobs are susceptible to computerization\n\nWe’ve heard stories about how self-driving cars and trucks will put millions of Americans out of work.', 'Figure 3.', 'Self-Driving Trucks Are Going to Hit Us Like a Human-Driven Truck\n\nI’d like to provide an alternate perspective.', 'Back in 1811 and 1812, a group of weavers led by Ned Ludd staged a rebellion, smashing the machine looms that were threatening their livelihood.', 'Ludd and his compatriots were right to be afraid.', 'The decades ahead were grim, as machines replaced human labor, and it took time for society to adjust.', 'Figure 4.', 'Source: Wikimedia Commons\n\nBut those weavers couldn’t imagine that their descendants would have more clothing than the kings and queens of Europe, that ordinary people would eat the fruits of summer in the depths of winter.', 'They couldn’t imagine that we’d tunnel through mountains and under the sea, we’d fly through the air, crossing continents in hours, we’d build cities in the desert with buildings a half mile high, that we’d put spacecraft in orbit around Jupiter, that we would eliminate so many scourges of disease!', 'And they couldn’t imagine that their children would find meaningful work bringing all of these things to life!', 'Figure 5.', 'Photo composite by Tim O’Reilly and Edie Freedman\n\nTo understand the future, it often helps to look backward.', 'I want to start here, with one of the world’s most heralded inventions.', 'Can you imagine the first woman (I imagine it was a woman) who built a controlled fire?', 'How amazed her companions were.', 'Perhaps afraid at first.', 'But soon warmed and fed by her boldness.', 'But even more important than fire itself was the ability to tell others about it!', 'It was language that was our first great invention, the ability to pass fire from mind to mind.', 'Figure 6.', 'Neanderthals.', 'Source: Wikimedia Commons\n\nThe invention of movable type and the book led to a remarkable flowering in the economy, as the discoverers of the new could pass the fire of knowledge to people not yet born and to those living thousands of miles away.', 'Figure 7.', 'The War Department Library in the Eisenhower Executive Office Building.', 'Photo: Tim O’Reilly\n\nThe Internet was the next great leap.', 'But the web browser—words and pictures online—was only a halfway house.', 'I was recen ...
# ========================================================
# len of each list of words 60
# ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']
# ````````````````````````````````````````````````````````
# ['tim', 'frick', 'products', 'reading', 'how', 'for']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 6
# ________________________________________________________
# ['Tim Frick offers simple tactics to make your own digital products and services more sustainable.Continue reading How to design for sustainability.']
# ========================================================
# len of each list of words 6
# ['tim', 'frick', 'products', 'reading', 'how', 'for']
# ````````````````````````````````````````````````````````
# ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 7
# ________________________________________________________
# ['WAN-Replicated Data, NoSQL Modeling, Sharing Roadmaps, and Shopping Statistics\n\nBedrockDB -- a simple, modular, WAN-replicated data foundation for global-scale applications.', "NoSQL Data Modeling Techniques -- for your first steps in 2009's Brave New (Data) World.", 'Roadmaps -- the different views of the product road map, for different audiences, is good advice.', '17 Staggering Statistics About Our Shopping Habits  -- 5.', '50% of online shoppers will increase the size of their orders just to hit the free shipping minimum.', '6.', 'An estimated two-thirds of the U.S. gross domestic product (GDP) comes from retail consumption.', 'Continue reading Four short links: 19 October 2016.']
# ========================================================
# len of each list of words 60
# ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']
# ````````````````````````````````````````````````````````
# ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19'], ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']]
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 8
# ________________________________________________________
# ['Using RUM to analyze HTTP vs. HTTPS in different world regions and across wireline, rural wireline, and wireless ISPs.Continue reading Understanding the performance penalty: HTTP vs. HTTPS.']
# ========================================================
# len of each list of words 19
# ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']
# ````````````````````````````````````````````````````````
# ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us', 'for', 'building', 'svg', 'animations', 'new', "o'reilly", 'training', 'center', 'boston', 'nov.', '1-2']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19'], ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https'], ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us',  ...
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 9
# ________________________________________________________
# ['Learn why animating SVG is different from animating in CSS, and work around some common hiccups you might experience along the way.Are you just getting started in SVG animation?', "Maybe you have been using SVGs as a background image, maybe you've started using SVGs as icons, or maybe you've just been meaning to dig into it.", 'This excerpt from the upcoming book SVG Animations is for you.', "We'll carefully go through what it takes to animate an SVG, why it's different from animating a div in CSS, and work around some common hiccups you might experience along the way.", "If you're interested in learning more, please join us for our in-person training, Building SVG Animations, at the new O'Reilly Training Center in Boston on Nov. 1-2.", 'Animating with CSS\nYou may have noticed that working with SVG code is familiar, mostly because an SVG has a DOM, just like standard HTML markup.', 'This is hugely valuable when working with CSS animations, as manipulating markup with CSS is already a very comfortable process for most front-end developers.', 'For a very brief review, let’s first establish that a CSS animation is created by defining two parameters.', 'The keyframes themselves:\n\n@keyframes animation-name-you-pick {\n\xa0\xa00% {\n\xa0\xa0\xa0background: blue;\n\xa0\xa0\xa0transform: translateX(0);\n\xa0}\n\xa0\xa050% {\n\xa0\xa0\xa0background: purple;\n\xa0\xa0\xa0transform: translateX(50px);\n\xa0}\n\xa0\xa0100% {\n\xa0\xa0\xa0background: red;\n\xa0\xa0\xa0transform: translateX(100px);\n\xa0}\n}\n\nNote\nKeyframe syntax h int:\nYou can also define from and to instead of percentages.', 'If you declare nothing in either the initial keyframe or the ending keyframe, the animation will use the default or declared properties on the element.', 'After you define the keyframe values, you have two options for animation syntax declaration.', 'Long form, with each declaration defined separately:\n\n.ball {\n  animation-name: animation-name-you-pick;\n  animation-duration: 2s;\n  animation-delay: 2s;\n  animation-iteration-count: 3;\n  animation-direction: alternate;\n  animation-timing-function: ease-in-out;\n  animation-fill-mode: forwards;\n}\nOr shorthand (my preferred method as it uses less code):\n\n.ball {\n\xa0 animation: animation-name-you-pick 2s 2s 3 alternate ease-in-out forwards;\n}\n\nAll of the above declarations are interchangeable in order in a space-separated list, except for the number values, which must be defined in the above order: duration, delay, and iteration count.', 'If we apply it to this very simple .ball div\n\n.ball {\n\xa0 border-radius: 50%;\n\xa0 width: 50px;\n\xa0 height: 50px;\n\xa0 margin: 20px; //so that it’s not hitting the edge of the page\n\xa0 background: black;\n}\n\n\nthe result is this, with interstitial states shown less opaque:\n\nAll of the resulting code in action is available in this demo.', 'For more information and further detail into each animation property, such as what animation-fill-mode is, what eases are available in CSS, and which properties are animatable, there is extensive information in Estelle Weyl’s book, Transitions and Animations in CSS\nOr you can also consult Dudley Storey’s CSS Animations book.', 'Animating with SVG\nLet’s say instead of drawing the ball with CSS, we had drawn it with SVG.', 'To get the same black circle as above, we would write:\n\n<svg width="70px" height="70px" viewBox="0 0 70 70">\n\xa0 <circle fill="black" cx="45" cy="45" r="25"/>\n</svg>\n\nWe define the radius as half of 50, so 25px.', 'Then we move the center of the circle on both the x and y axis (cx and cy) to half the radius plus that 20px margin we added in the CSS.', 'We could also use margin to move it, but here I’m illustrating that you can draw coordinates directly in the SVG itself.', 'The viewBox has to be larger to accommodate these coordinates, though, so it is the width plus the margin of space to the edge.', 'Now, if we place a class on the whole SVG called "ball," using the same ...
# ========================================================
# len of each list of words 60
# ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us', 'for', 'building', 'svg', 'animations', 'new', "o'reilly", 'training', 'center', 'boston', 'nov.', '1-2']
# ````````````````````````````````````````````````````````
# ['understand', 'how', 'capital', 'one', 'embraced', 'continuous', 'learn', 'core', 'principles', 'best', 'practices', 'behind', 'reading', 'part', 'pipeline', 'why', 'continuous', 'essential']
# ...
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 57
# ________________________________________________________
# ['LinkedIn CEO Jeff Weiner on what LinkedIn tells us about how we can better match supply and demand in key skills.Continue reading A conversation with Jeff Weiner.']
# ========================================================
# len of each list of words 18
# ['linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'us', 'how', 'we', 'can', 'better', 'key', 'reading', 'a', 'conversation', 'with', 'jeff', 'weiner']
# ````````````````````````````````````````````````````````
# ['keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'continue', 'reading', 'on-demand', 'for', 'blood']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19'], ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https'], ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us',  ...
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 58
# ________________________________________________________
# ["Keller Rinaudo's company, Zipline, is using on-demand technology and drones to deliver medical supplies to areas with poor infrastructure and transportation.", 'Continue reading On-demand drone delivery for blood and medicine.']
# ========================================================
# len of each list of words 12
# ['keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'continue', 'reading', 'on-demand', 'for', 'blood']
# ````````````````````````````````````````````````````````
# ['niantic', 'founder', 'ceo', 'john', 'hanke', 'his', 'creating', 'pokémon', 'go', 'what', 'us', 'future', 'entertainment.continue', 'reading', 'the', 'city', 'a', 'conversation', 'with', 'john', 'hanke', 'niantic', 'creator', 'pokémon', 'go']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19'], ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https'], ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us',  ...
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 59
# ________________________________________________________
# ['Niantic founder and CEO John Hanke talks about his motivations in creating the Pokémon GO app and what it teaches us about the future of entertainment.Continue reading The augmented city: A conversation with John Hanke of Niantic, creator of Pokémon GO.']
# ========================================================
# len of each list of words 25
# ['niantic', 'founder', 'ceo', 'john', 'hanke', 'his', 'creating', 'pokémon', 'go', 'what', 'us', 'future', 'entertainment.continue', 'reading', 'the', 'city', 'a', 'conversation', 'with', 'john', 'hanke', 'niantic', 'creator', 'pokémon', 'go']
# ````````````````````````````````````````````````````````
# ['natalie', 'foster', 'aspen', 'institute', 'hosts', 'conversation', 'with', 'andy', 'stern', 'raising', 'floor', 'elizabeth', 'rhodes', 'who', 'heading', 'up', 'y', 'combinator’s', 'new', 'universal', 'basic', 'experiments', 'continue', 'reading', 'is', 'for', 'universal', 'basic']
# [['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots'], ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding'], ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning'], ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world'], ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob'], ['tim', 'frick', 'products', 'reading', 'how', 'for'], ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19'], ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https'], ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us',  ...
# ====|=======|=========|=======|===========|=======|=====
# Blog number: 60
# ________________________________________________________
# ['Natalie Foster of the Aspen Institute hosts a conversation with Andy Stern, author of Raising the Floor, and Elizabeth Rhodes, who is heading up Y Combinator’s new universal basic income experiments.', 'Continue reading Is it time for a universal basic income?.']
# ========================================================
# len of each list of words 28
# ['natalie', 'foster', 'aspen', 'institute', 'hosts', 'conversation', 'with', 'andy', 'stern', 'raising', 'floor', 'elizabeth', 'rhodes', 'who', 'heading', 'up', 'y', 'combinator’s', 'new', 'universal', 'basic', 'experiments', 'continue', 'reading', 'is', 'for', 'universal', 'basic']
# ````````````````````````````````````````````````````````

# %%
len(master_list) ####checking len of the list with words for each blog, resulting in 60 because we do have 60 blogs pulled from the site
# Out:
# 60

# %%
master_list ##content of the list
# Out:
# [['the',
#   'o’reilly',
#   'bots',
#   'podcast',
#   'how',
#   'bots',
#   'way',
#   'companies',
#   'with',
#   'customers.customer',
#   'key',
#   'for',
#   'bots—one',
#   'first',
#   'we',
#   'when',
#   'we',
#   'world',
#   'full',
#   'ai-enabled',
#   'conversational',
#   'in',
#   'episode',
#   'o’reilly',
#   'bots',
#   'podcast',
#   'pete',
#   'skomoroch',
#   'i',
#   'with',
#   'founders',
#   'companies',
#   'have',
#   'bots',
#   'help',
#   'consumers',
#   'companies',
#   'each',
#   'reading',
#   'michael',
#   'schneider',
#   'rachel',
#   'law',
#   'alyx',
#   'baldwin',
#   'customer',
#   'with',
#   'bots'],
#  ['the',
#   "o'reilly",
#   'radar',
#   'podcast',
#   'prediction',
#   'cognitive',
#   'biases',
#   'how',
#   'brains',
#   'come',
#   'week',
#   'episode',
#   'i',
#   'chat',
#   'with',
#   'sam',
#   'wang',
#   'professor',
#   'neuroscience',
#   'biology',
#   'princeton',
#   'wang',
#   'co-founder',
#   'princeton',
#   'election',
#   'consortium',
#   'focused',
#   'predicting',
#   'u.s.',
#   'national',
#   'elections',
#   'we',
#   'prediction',
#   'crazy',
#   'election',
#   'cycle',
#   'role',
#   'neuroscience',
#   'have',
#   'played',
#   'we',
#   'current',
#   'research',
#   'wang',
#   'his',
#   'working',
#   'u.s',
#   'brain',
#   'initiative',
#   'powerful',
#   'role',
#   'governments',
#   'play',
#   'research.continue',
#   'reading',
#   'sam',
#   'wang',
#   'predicting',
#   'election',
#   'finding'],
#  ['the',
#   'o’reilly',
#   'data',
#   'show',
#   'podcast',
#   'christopher',
#   'nguyen',
#   'early',
#   'apache',
#   'spark',
#   'learning',
#   'for',
#   'china',
#   'ai.in',
#   'episode',
#   'o’reilly',
#   'data',
#   'show',
#   'i',
#   'with',
#   'christopher',
#   'nguyen',
#   'ceo',
#   'co-founder',
#   'arimo',
#   'nguyen',
#   'arimo',
#   'were',
#   'first',
#   'proponents',
#   'apache',
#   'spark',
#   'alluxio',
#   'most',
#   'recently',
#   'arimo’s',
#   'products',
#   'has',
#   'relied',
#   'learning',
#   'range',
#   'business',
#   'problems.continue',
#   'reading',
#   'why',
#   'businesses',
#   'pay',
#   'learning'],
#  ['kid',
#   'privacy',
#   'chinese',
#   'creation',
#   'reality',
#   'rocks',
#   'chaos',
#   'monkey',
#   '2',
#   'digital',
#   'defenders',
#   'free',
#   'cc-licensed',
#   'kids',
#   'booklet',
#   'privacy',
#   'via',
#   'cory',
#   'doctorow',
#   'news',
#   'ideas',
#   'are',
#   "n't",
#   'intrinsically',
#   'valuable',
#   'executed',
#   'can',
#   'be',
#   'valuable',
#   'chinese',
#   'hardware',
#   'can',
#   'execute',
#   'faster',
#   'american',
#   'this',
#   'up',
#   'kickstarter',
#   'products',
#   'up',
#   'for',
#   'shenzhen',
#   'before',
#   'kickstarter',
#   'closes',
#   'via',
#   'boingboing',
#   'the',
#   'world',
#   'getting',
#   'better',
#   'nobody',
#   'knows',
#   'it',
#   'in',
#   'britain',
#   '10',
#   '%',
#   'people',
#   'world'],
#  ['if',
#   'we',
#   'let',
#   'put',
#   'us',
#   'work',
#   'will',
#   'be',
#   'because',
#   'failure',
#   'lack',
#   'will',
#   'better',
#   'future',
#   'full',
#   'video',
#   'from',
#   'tim',
#   "o'reilly",
#   'white',
#   'house',
#   'frontiers',
#   'conference',
#   'i',
#   'had',
#   'honor',
#   'be',
#   'warmup',
#   'for',
#   'president',
#   'obama',
#   'white',
#   'house',
#   'frontiers',
#   'conference',
#   'carnegie',
#   'mellon',
#   'university',
#   'pittsburgh',
#   'here',
#   'prepared',
#   'from',
#   'i',
#   'as',
#   'watch',
#   'video',
#   'what',
#   'i',
#   'ended',
#   'up',
#   'exactly',
#   'what',
#   'i',
#   'had',
#   'written',
#   'but',
#   'reasonably',
#   'close',
#   'hearing',
#   'bob'],
#  ['tim', 'frick', 'products', 'reading', 'how', 'for'],
#  ['wan-replicated',
#   'data',
#   'nosql',
#   'modeling',
#   'sharing',
#   'roadmaps',
#   'shopping',
#   'statistics',
#   'bedrockdb',
#   'wan-replicated',
#   'foundation',
#   'for',
#   'global-scale',
#   'nosql',
#   'data',
#   'modeling',
#   'techniques',
#   'for',
#   'first',
#   '2009',
#   'brave',
#   'new',
#   'data',
#   'world',
#   'roadmaps',
#   'views',
#   'product',
#   'road',
#   'for',
#   'good',
#   '17',
#   'staggering',
#   'statistics',
#   'about',
#   'our',
#   'shopping',
#   'habits',
#   '5',
#   '50',
#   '%',
#   'will',
#   'just',
#   'hit',
#   'free',
#   '6',
#   'an',
#   'estimated',
#   'u.s.',
#   'gross',
#   'product',
#   'gdp',
#   'comes',
#   'from',
#   'retail',
#   'consumption',
#   'continue',
#   'reading',
#   'four',
#   'links',
#   '19'],
#  ['using',
#   'rum',
#   'http',
#   'vs.',
#   'https',
#   'world',
#   'regions',
#   'wireline',
#   'rural',
#   'wireline',
#   'wireless',
#   'isps.continue',
#   'reading',
#   'understanding',
#   'performance',
#   'penalty',
#   'http',
#   'vs.',
#   'https'],
#  ['learn',
#   'why',
#   'svg',
#   'from',
#   'css',
#   'work',
#   'common',
#   'hiccups',
#   'experience',
#   'way.are',
#   'just',
#   'getting',
#   'svg',
#   'maybe',
#   'have',
#   'been',
#   'using',
#   'svgs',
#   'background',
#   'using',
#   'svgs',
#   'just',
#   'been',
#   'this',
#   'excerpt',
#   'from',
#   'upcoming',
#   'book',
#   'svg',
#   'animations',
#   'for',
#   'we',
#   'carefully',
#   'go',
#   'what',
#   'svg',
#   'why',
#   'from',
#   'css',
#   'work',
#   'common',
#   'hiccups',
#   'experience',
#   'way',
#   'if',
#   'learning',
#   'please',
#   'join',
#   'us',
#   'for',
#   'building',
#   'svg',
#   'animations',
#   'new',
#   "o'reilly",
#   'training',
#   'center',
#   'boston',
#   'nov.',
#   '1-2'],
#  ['understand',
#   'how',
#   'capital',
#   'one',
#   'embraced',
#   'continuous',
#   'learn',
#   'core',
#   'principles',
#   'best',
#   'practices',
#   'behind',
#   'reading',
#   'part',
#   'pipeline',
#   'why',
#   'continuous',
#   'essential'],
#  ['in',
#   'video',
#   'brian',
#   'l.',
#   'gorman',
#   'uncovers',
#   'relationship',
#   'between',
#   'efficiency',
#   'branch',
#   'prediction',
#   'when',
#   'executing',
#   'java.continue',
#   'reading',
#   'does',
#   'run',
#   'faster',
#   'unsorted',
#   'java'],
#  ['a',
#   'common',
#   'java',
#   'pass',
#   'by',
#   'reference',
#   'language',
#   'in',
#   'video',
#   'brian',
#   'l.',
#   'gorman',
#   'exposes',
#   'workings',
#   'pass',
#   'by',
#   'value.continue',
#   'reading',
#   'is',
#   'java',
#   'pass',
#   'by',
#   'reference',
#   'pass',
#   'by',
#   'value'],
#  ['roberto',
#   'di',
#   'cosmo',
#   'reveals',
#   'behind',
#   'launch',
#   'software',
#   'heritage',
#   'project',
#   'has',
#   '3',
#   'billion',
#   'unique',
#   'code',
#   'files',
#   '650',
#   'unique',
#   'commits.continue',
#   'reading',
#   'why',
#   'how',
#   'software',
#   'heritage',
#   'building',
#   'universal'],
#  ['lauri',
#   'apple',
#   'zalando',
#   'how',
#   'company.continue',
#   'reading',
#   'building',
#   'culture',
#   'europe’s',
#   'largest',
#   'fashion',
#   'platform'],
#  ['open',
#   'licenses',
#   'have',
#   'us',
#   'well',
#   'for',
#   'but',
#   'cory',
#   'doctorow',
#   'need',
#   'help',
#   'we’re',
#   'going',
#   'era',
#   'which',
#   'computers',
#   'bodies',
#   'continue',
#   'reading',
#   'how',
#   'got',
#   'here'],
#  ['karen',
#   'sandler',
#   'freedom',
#   'underlies',
#   'effectively',
#   'problems',
#   'we',
#   'need',
#   'new',
#   'way',
#   'relation',
#   'justice',
#   'causes.continue',
#   'reading',
#   'is',
#   'freedom',
#   'justice'],
#  ['awesome',
#   'falsehoods',
#   'neural',
#   'network',
#   'vision',
#   'toy',
#   'family',
#   'robots',
#   'over-engineered',
#   'software',
#   'awesome',
#   'falsehoods',
#   'great',
#   'collections',
#   'lies',
#   'we',
#   'programmers',
#   'what',
#   'email',
#   'what',
#   'networks',
#   'favourite',
#   'zones',
#   'how',
#   'do',
#   'neural',
#   'networks',
#   'see',
#   'the',
#   'world',
#   'youtube',
#   'video',
#   'explainer',
#   'anki',
#   'cozmo',
#   'robot',
#   'compare',
#   'nxrobo',
#   'big-i',
#   'first',
#   'personalized',
#   'family',
#   'robot',
#   'big-i',
#   'natural-interaction',
#   'robot',
#   'with',
#   '3d',
#   'vision',
#   'voice',
#   'programming',
#   'perception',
#   'it',
#   'can',
#   'needs',
#   'ten',
#   'modern',
#   'software',
#   'over-engineering',
#   'mistakes'],
#  ['lessons',
#   'learned',
#   'fastly',
#   'how',
#   'build',
#   'robust',
#   'contains',
#   'properly',
#   'communicates',
#   'prevent',
#   'recurrence.in',
#   'complex',
#   'failure',
#   'rule',
#   'and',
#   'failure',
#   'can',
#   'have',
#   'wide',
#   'ranging',
#   'especially',
#   'when',
#   'responsible',
#   'for',
#   '1',
#   'per',
#   'internet',
#   'as',
#   'content',
#   'delivery',
#   'network',
#   'cdn',
#   'fastly',
#   'large',
#   'global',
#   'environment',
#   'which',
#   'faces',
#   'both',
#   'from',
#   'reliability',
#   'perspective',
#   'as',
#   'we',
#   'put',
#   'place',
#   'robust',
#   'would',
#   'us',
#   'rapidly',
#   'contain',
#   'would',
#   'ensure',
#   'communication',
#   'would',
#   'flow',
#   'effectively',
#   'both',
#   'within',
#   'company'],
#  ['the',
#   'beyond',
#   'twelve-factor',
#   'app',
#   'i',
#   'present',
#   'new',
#   'guidelines',
#   'builds',
#   'heroku’s',
#   '12',
#   'factors',
#   'reflects',
#   'best',
#   'practices',
#   'for',
#   'building',
#   'cloud-native',
#   'i',
#   'have',
#   'changed',
#   'priority',
#   'factors',
#   'concept',
#   '“api',
#   'first”',
#   'be',
#   'considerations',
#   'for',
#   'will',
#   'be',
#   'running',
#   'cloud',
#   'these',
#   'new',
#   '15-factor',
#   'guidelines',
#   'one',
#   'codebase',
#   'api',
#   'first',
#   'dependency',
#   'design',
#   'build',
#   'release',
#   'run',
#   'configuration',
#   'credentials',
#   'code',
#   'logs',
#   'disposability',
#   'backing',
#   'environment',
#   'parity',
#   'administrative',
#   'processes',
#   'port',
#   'binding',
#   'stateless',
#   'processes'],
#  ['5',
#   'questions',
#   'for',
#   'binu',
#   'ramakrishnan',
#   'insights',
#   'centralized',
#   'ci/cd',
#   'environments',
#   'common',
#   'protection',
#   'for',
#   'recently',
#   'with',
#   'binu',
#   'ramakrishnan',
#   'principal',
#   'engineer',
#   'yahoo',
#   'with',
#   'centralized',
#   'continuous',
#   'continuous',
#   'ci/cd',
#   'platform',
#   'protect',
#   'here',
#   'highlights',
#   'from',
#   '1',
#   'how',
#   'can',
#   'ci/cd',
#   'platform',
#   'posture',
#   'lately',
#   'has',
#   'from',
#   'environments',
#   'favor',
#   'ci/cd',
#   'environments',
#   'a',
#   'factor',
#   'behind',
#   'platform',
#   'economies',
#   'in',
#   'build',
#   'environments',
#   'each',
#   'build',
#   'the',
#   'risk',
#   'exposure',
#   'from',
#   'limited',
#   'because',
#   'each',
#   'likely'],
#  ['kris',
#   'borchers',
#   'javascript.continue',
#   'reading',
#   'evolving',
#   'javascript',
#   'ecosystem'],
#  ['mark',
#   'shuttleworth',
#   'next',
#   'likely',
#   'come',
#   'from',
#   'laptop',
#   'pc',
#   'beating',
#   'neighbor',
#   'web',
#   'cloud.continue',
#   'reading',
#   'brilliant',
#   'pebbles'],
#  ['danese',
#   'cooper',
#   'explores',
#   'innersource',
#   'within',
#   'walls',
#   'reading',
#   'how',
#   'innersource',
#   'like',
#   'flossing'],
#  ['watch',
#   'highlights',
#   'covering',
#   'business',
#   'from',
#   'oscon',
#   'london',
#   '2016.people',
#   'from',
#   'community',
#   'came',
#   'for',
#   'oscon',
#   'london',
#   '2016',
#   'below',
#   'find',
#   'links',
#   'highlights',
#   'from',
#   'event',
#   'brilliant',
#   'pebbles',
#   'mark',
#   'shuttleworth',
#   'next',
#   'likely',
#   'come',
#   'from',
#   'laptop',
#   'pc',
#   'beating',
#   'neighbour',
#   'web',
#   'cloud',
#   'watch',
#   '``',
#   'brilliant',
#   'pebbles',
#   'how',
#   'got',
#   'here',
#   'open',
#   'licenses',
#   'have',
#   'us',
#   'well',
#   'for',
#   'but',
#   'cory',
#   'doctorow',
#   'need',
#   'help',
#   'we’re',
#   'going',
#   'era',
#   'which',
#   'computers',
#   'bodies',
#   'watch'],
#  ['male',
#   'allies',
#   'learning',
#   'maps',
#   'machine',
#   'learning',
#   'biology',
#   '``',
#   'the',
#   'attention',
#   'merchants',
#   'male',
#   'allies',
#   'bingo',
#   'card',
#   'via',
#   'anna',
#   'christison',
#   'so',
#   'you',
#   'want',
#   'learn',
#   'physics',
#   'really',
#   'learning',
#   'at',
#   "o'reilly",
#   'we',
#   'been',
#   'hard',
#   'learning',
#   'paths',
#   'for',
#   'untargeted',
#   'metabolomics',
#   'using',
#   'deep',
#   'learning',
#   'this',
#   'untargeted',
#   'unbiased',
#   'every',
#   'change',
#   'cell',
#   'gives',
#   'us',
#   'for',
#   'biology',
#   'learning',
#   'has',
#   'been',
#   'key',
#   'getting',
#   'here',
#   'reliably',
#   'the',
#   'attention',
#   'merchants',
#   'the',
#   'epic'],
#  ['5',
#   'questions',
#   'for',
#   'timothy',
#   'gallo',
#   'allan',
#   'liska',
#   'insights',
#   'common',
#   'ransomware',
#   'how',
#   'find',
#   'balance',
#   'between',
#   'risks',
#   'productivity.i',
#   'recently',
#   'with',
#   'ransomware',
#   'co-authors',
#   'allan',
#   'liska',
#   'consulting',
#   'engineer',
#   'recorded',
#   'future',
#   'timothy',
#   'gallo',
#   'cyber',
#   'engineer',
#   'symantec',
#   'challenges',
#   'ransomware',
#   'how',
#   'here',
#   'highlights',
#   'from',
#   '1',
#   'can',
#   'explain',
#   'common',
#   'for',
#   'ransomware',
#   'how',
#   'have',
#   'persisted',
#   'the',
#   'common',
#   'email',
#   'via',
#   'web',
#   'using',
#   'exploits',
#   'kits',
#   'there',
#   'have',
#   'been',
#   'ransomware',
#   'like',
#   'keranger'],
#  ['amazing',
#   'china',
#   'deep',
#   'learning',
#   'memory',
#   'vr',
#   'spaces',
#   'javascript',
#   'song',
#   'what',
#   '$',
#   '50',
#   'buys',
#   'you',
#   'at',
#   'huaqianbei',
#   'markets',
#   'shenzhen',
#   'was',
#   'blown',
#   '$',
#   '6',
#   'for',
#   'gsm',
#   'chipset',
#   'cpu',
#   'lcd',
#   'battery',
#   'pcb',
#   'housing',
#   'watch',
#   'band',
#   'microusb',
#   'cable',
#   'box',
#   'and',
#   'labor',
#   'differentiable',
#   'neural',
#   'computers',
#   'deepmind',
#   'latest',
#   'work',
#   'putting',
#   'learning',
#   'lets',
#   'computers',
#   'learn',
#   'form',
#   'navigate',
#   'complex',
#   'modalvr',
#   'nolan',
#   'bushnell',
#   'new',
#   'which',
#   'hopes',
#   'for',
#   'vr',
#   'what'],
#  ['this',
#   'free',
#   'webcast',
#   'provides',
#   'quick',
#   'lesson',
#   'updating',
#   'relational',
#   'oct.',
#   '26',
#   '2pm',
#   'pt.virtually',
#   'every',
#   'requires',
#   'persistent',
#   'one',
#   'best',
#   'features',
#   'spring',
#   'framework',
#   'how',
#   'easily',
#   'provides',
#   'work',
#   'with',
#   'relational',
#   'this',
#   'free',
#   'webcast',
#   'being',
#   'held',
#   'oct.',
#   '26',
#   '2pm',
#   'pt',
#   'will',
#   'how',
#   'use',
#   'spring',
#   'jdbctemplate',
#   'updating',
#   'relational',
#   'very',
#   'well',
#   'handling',
#   'exceptions',
#   'using',
#   'discussions',
#   'both',
#   'spring',
#   'jpa',
#   'working',
#   'with',
#   'nosql',
#   'will',
#   'be',
#   'no',
#   'previous',
#   'spring',
#   'experience'],
#  ['author',
#   'mark',
#   'richards',
#   'walks',
#   '10',
#   'common',
#   'pitfalls',
#   'provides',
#   'for',
#   'preface',
#   'in',
#   'late',
#   '2006',
#   'soa',
#   'was',
#   'craze',
#   'companies',
#   'were',
#   'jumping',
#   'bandwagon',
#   'embracing',
#   'soa',
#   'before',
#   'fully',
#   'understanding',
#   'very',
#   'complex',
#   'those',
#   'companies',
#   'embarked',
#   'soa',
#   'projects',
#   'found',
#   'constant',
#   'with',
#   'granularity',
#   'performance',
#   'particular',
#   'change',
#   'comes',
#   'with',
#   'soa',
#   'as',
#   'result',
#   'companies',
#   'either',
#   'soa',
#   'efforts',
#   'built',
#   'hybrid',
#   'not',
#   'fulfill',
#   'promises',
#   'soa',
#   'today',
#   'we',
#   'poised',
#   'repeat',
#   'experience',
#   'with'],
#  ['a',
#   'look',
#   'expanding',
#   'biotech',
#   'landscape',
#   'sxsw',
#   'south',
#   'by',
#   'southwest',
#   'sxsw',
#   'film',
#   'festival',
#   'happens',
#   'austin',
#   'texas',
#   'every',
#   'march',
#   'since',
#   '1987',
#   'has',
#   'evolved',
#   'become',
#   'launching',
#   'pad',
#   'for',
#   'wide',
#   'range',
#   'figure',
#   '1-1',
#   'figure',
#   '1-1',
#   'the',
#   'sxsw',
#   'festival',
#   'phylogenetic',
#   'reflects',
#   'cultural',
#   'the',
#   'rumblings',
#   'biotech',
#   'wave',
#   'closer',
#   'look',
#   'evolving',
#   'programming',
#   'ecosystem',
#   'biotech',
#   'labs',
#   'labs',
#   'like',
#   'craig',
#   'venter',
#   '23andme',
#   'ubiome',
#   'genspace',
#   'la',
#   'pailasse',
#   'ginkgo',
#   'bioworks',
#   'biobuilder'],
#  ['the',
#   'o’reilly',
#   'bots',
#   'podcast',
#   'bots',
#   'can',
#   'respond',
#   'groups',
#   'users.the',
#   'workplace',
#   'rich',
#   'venue',
#   'for',
#   'bots',
#   'help',
#   'with',
#   'productivity',
#   'collaboration',
#   'in',
#   'episode',
#   'o’reilly',
#   'bots',
#   'podcast',
#   'pete',
#   'skomoroch',
#   'i',
#   'focus',
#   'workplace',
#   'bots',
#   'we',
#   'begin',
#   'by',
#   'with',
#   'jassim',
#   'latif',
#   'head',
#   'partnerships',
#   'slack',
#   'bots',
#   'written',
#   'by',
#   'for',
#   'human',
#   'resources',
#   '“we’re',
#   'building',
#   'future',
#   'where',
#   'value',
#   'people',
#   'building',
#   'slack',
#   'far',
#   'value',
#   'slack',
#   '”',
#   'latif',
#   'reading',
#   'jassim',
#   'latif'],
#  ['the',
#   'o’reilly',
#   'design',
#   'podcast',
#   'design',
#   'creating',
#   'right',
#   'environment.in',
#   'week’s',
#   'design',
#   'podcast',
#   'i',
#   'with',
#   'kristin',
#   'skinner',
#   'adaptive',
#   'path',
#   'head',
#   'capital',
#   'one',
#   'co-author',
#   'org',
#   'design',
#   'for',
#   'design',
#   'orgs',
#   'we',
#   'what',
#   'we',
#   'can',
#   'learn',
#   'from',
#   'golden',
#   'state',
#   'warriors.continue',
#   'reading',
#   'kristin',
#   'skinner'],
#  ['the',
#   'o’reilly',
#   'data',
#   'show',
#   'podcast',
#   'natalino',
#   'busa',
#   'feature',
#   'engineering',
#   'predictive',
#   'episode',
#   'o’reilly',
#   'data',
#   'show',
#   'o’reilly’s',
#   'editor',
#   'jenn',
#   'webb',
#   'with',
#   'natalino',
#   'busa',
#   'predictive',
#   'challenges',
#   'feature',
#   'engineering',
#   'new',
#   'class',
#   'enabling',
#   'features',
#   'emerge',
#   'from',
#   'patterns',
#   'within',
#   'they',
#   'relationship',
#   'between',
#   'predictive',
#   'high-quality',
#   'how',
#   'learning',
#   'being',
#   'used',
#   'financial',
#   'reading',
#   'understanding',
#   'predictive'],
#  ['take',
#   'learning',
#   'followed',
#   'previous',
#   'post',
#   'learned',
#   'how',
#   'gpu-accelerated',
#   'tensorflow',
#   'create',
#   'classifier',
#   'linux',
#   'computer',
#   'honestly',
#   'process',
#   'classifying',
#   'consuming',
#   'laptop',
#   'have',
#   'want',
#   'classify',
#   'enter',
#   'lot',
#   'code',
#   'just',
#   'classify',
#   'thankfully',
#   'not',
#   'well',
#   'publicized',
#   'can',
#   'run',
#   'inception',
#   'classifier—or',
#   'classifier—live',
#   'camera-equipped',
#   'phone',
#   'you',
#   'need',
#   'point',
#   'camera',
#   'what',
#   'classify',
#   'tensorflow',
#   'will',
#   'what',
#   'you',
#   'can',
#   'use',
#   'tensorflow',
#   'raspberry',
#   'pi',
#   'but',
#   'for',
#   'i',
#   'will',
#   'be',
#   'using',
#   'android',
#   'i’ll'],
#  ['cake',
#   'cutting',
#   'tea',
#   'making',
#   'google',
#   'interviewing',
#   'automation',
#   'puzzling',
#   'fair',
#   'cake-cutting',
#   'but',
#   'april',
#   'computer',
#   'expectations',
#   'by',
#   'posting',
#   'paper',
#   'envy-free',
#   'cake-cutting',
#   'whose',
#   'running',
#   'number',
#   'players',
#   'not',
#   'preferences',
#   '[',
#   ']',
#   'the',
#   'extraordinarily',
#   'complex',
#   'cake',
#   'n',
#   'players',
#   'can',
#   'require',
#   'n^n^n^n^n^n',
#   'roughly',
#   'equivalent',
#   'number',
#   'cuts',
#   'even',
#   'for',
#   'just',
#   'handful',
#   'players',
#   'number',
#   'greater',
#   'number',
#   'universe',
#   'you',
#   'ca',
#   "n't",
#   'have',
#   'cake',
#   'compute',
#   'english',
#   'man',
#   'spends',
#   '11',
#   'hours'],
#  ['word',
#   'embedding',
#   'natural',
#   'language',
#   'processing.word',
#   'embedding',
#   'words',
#   'vectors',
#   'whose',
#   'relative',
#   'correlate',
#   'with',
#   'this',
#   'unsupervised',
#   'learning',
#   'natural',
#   'language',
#   'processing',
#   'nlp',
#   'encode',
#   'words',
#   'which',
#   'provide',
#   'no',
#   'useful',
#   'regarding',
#   'relationships',
#   'exist',
#   'between',
#   'words',
#   'word',
#   'embedding',
#   'nlp',
#   'whereby',
#   'words',
#   'phrases',
#   'from',
#   'vocabulary',
#   'vectors',
#   'real',
#   'numbers',
#   'low-dimensional',
#   'relative',
#   'vocabulary',
#   'between',
#   'vectors',
#   'correlate',
#   'with',
#   'words’',
#   'for',
#   'example',
#   'let’s',
#   'words',
#   'woman',
#   'queen',
#   'king',
#   'we',
#   'can',
#   'get',
#   'vector'],
#  ['insider',
#   "o'reilly",
#   'security',
#   'conference',
#   'proposal',
#   'process',
#   'rejection',
#   'o’reilly',
#   'security',
#   'conference',
#   'we’ve',
#   'had',
#   'great',
#   'from',
#   'folks',
#   'especially',
#   'who',
#   'looking',
#   'forward',
#   'what',
#   'works',
#   'with',
#   'like-minded',
#   'professionals',
#   'we’ve',
#   'received',
#   'queries',
#   'process',
#   'for',
#   'handling',
#   'call',
#   'for',
#   'proposals',
#   'cfp',
#   'in',
#   'we’ll',
#   'be',
#   'quite',
#   'bit',
#   'event',
#   'we',
#   'want',
#   'present',
#   'feedback',
#   'from',
#   'cfp',
#   'process',
#   'bit',
#   'version',
#   '“behind',
#   'music.”',
#   'tune',
#   'next',
#   'week',
#   'when',
#   'we’ll',
#   'follow',
#   'up',
#   'with',
#   'post'],
#  ['learn',
#   'how',
#   'capital',
#   'one',
#   'continuous',
#   'release',
#   'process',
#   'common',
#   'roadblocks.continue',
#   'reading',
#   'making',
#   'continuous',
#   'reality',
#   'large',
#   'enterprise'],
#  ['the',
#   'o’reilly',
#   'security',
#   'podcast',
#   'coarse-grained',
#   'embracing',
#   'ephemeral',
#   'empathy',
#   'for',
#   'everyone.in',
#   'episode',
#   'i',
#   'with',
#   'dan',
#   'kaminsky',
#   'founder',
#   'chief',
#   'white',
#   'ops',
#   'we',
#   'what',
#   'national',
#   'institutes',
#   'health',
#   'nih',
#   'for',
#   'would',
#   'look',
#   'like',
#   'pros',
#   'cons',
#   'docker',
#   'ephemeral',
#   'how',
#   'listening',
#   'people',
#   'better',
#   'can',
#   'for',
#   'everyone.continue',
#   'reading',
#   'dan',
#   'kaminsky',
#   'creating',
#   'nih',
#   'for'],
#  ['twitter',
#   'financially',
#   'vr',
#   'skeptically',
#   'electronica',
#   'originally',
#   'stack',
#   'overflow',
#   'competitively',
#   'twitter',
#   'buyout',
#   'financial',
#   'analysis',
#   'somewhere',
#   'near',
#   'half',
#   'billion',
#   'costs',
#   'need',
#   'be',
#   'and',
#   'firing',
#   'people',
#   'being',
#   'general',
#   'bastard',
#   'it',
#   'jack',
#   'dorsey',
#   'burning',
#   'half',
#   'billion',
#   'per',
#   "n't",
#   'business',
#   'via',
#   'marginal',
#   'revolution',
#   'carmack',
#   'keynote',
#   'oculus',
#   '3',
#   '``',
#   'we',
#   '[',
#   'vr',
#   'community',
#   ']',
#   'coasting',
#   'novelty',
#   'wonder',
#   'being',
#   'people',
#   'have',
#   'never',
#   'before',
#   'he',
#   'continued',
#   '``',
#   'but'],
#  ['this',
#   'report',
#   'explores',
#   'how',
#   'political',
#   'helps',
#   'everything',
#   'from',
#   'voter',
#   'contacts',
#   'prologue',
#   'the',
#   'role',
#   'data',
#   'campaigns',
#   'andrew',
#   'therriault',
#   'was',
#   'democratic',
#   'national',
#   'committee',
#   'director',
#   'data',
#   'science',
#   'from',
#   '2014',
#   '2016',
#   'leading',
#   'voter',
#   'used',
#   'by',
#   'democratic',
#   'campaigns',
#   'watching',
#   'news',
#   'coverage',
#   '2016',
#   'presidential',
#   'race',
#   'easy',
#   'election',
#   'unlike',
#   'come',
#   'before',
#   'behind',
#   'campaigns',
#   'continuing',
#   'has',
#   'been',
#   'underway',
#   'for',
#   'modern',
#   'campaigns',
#   'us',
#   'have',
#   'become',
#   'reliant',
#   'with',
#   'each',
#   'election'],
#  ['this',
#   'chapter',
#   'from',
#   'lean',
#   'ux',
#   '2nd',
#   'edition',
#   'how',
#   'blending',
#   'lean',
#   'ux',
#   'agile',
#   'can',
#   'create',
#   'productive',
#   'collaborative',
#   'process',
#   'agile',
#   'now',
#   'at',
#   'huge',
#   'products',
#   'like',
#   'amazon’s',
#   'kindle',
#   'apple’s',
#   'user',
#   'experience',
#   'ux',
#   'but',
#   'agile',
#   'work',
#   'with',
#   'ux',
#   'continues',
#   'be',
#   'challenge',
#   'for',
#   'companies',
#   'in',
#   'chapter',
#   'we',
#   'review',
#   'how',
#   'lean',
#   'ux',
#   'can',
#   'fit',
#   'within',
#   'popular',
#   'flavor',
#   'agile—scrum—and',
#   'how',
#   'blending',
#   'lean',
#   'ux',
#   'agile',
#   'can',
#   'create',
#   'productive'],
#  ['crafted',
#   'by',
#   'experienced',
#   'practitioners',
#   'patterns',
#   'can',
#   'flexible',
#   'resilient',
#   'change',
#   'easier',
#   'encountered',
#   'patterns',
#   'passing',
#   'nutshell',
#   'general',
#   'can',
#   'use',
#   'crafted',
#   'by',
#   'experienced',
#   'practitioners',
#   'patterns',
#   'can',
#   'flexible',
#   'resilient',
#   'change',
#   'easier',
#   'so',
#   'patterns',
#   'part',
#   'here',
#   'five',
#   'reasons',
#   '1',
#   'make',
#   'life',
#   'easier',
#   'by',
#   'not',
#   'reinventing',
#   'wheel',
#   'there’s',
#   'constant',
#   'no',
#   'projects',
#   'will',
#   'late',
#   'budget',
#   'it’s',
#   'change',
#   'change',
#   'when',
#   'requirements',
#   'change',
#   'grow',
#   'new',
#   'features',
#   'when',
#   'performance',
#   'we’re'],
#  ['best',
#   'practices',
#   'for',
#   'web',
#   'web',
#   'web',
#   'not',
#   'paying',
#   'enough',
#   'websites’',
#   'performance',
#   'and',
#   'we',
#   'users',
#   'paying',
#   'for',
#   'it’s',
#   'for',
#   'website',
#   'creators',
#   'understand',
#   'what',
#   'harms',
#   'performance',
#   'what',
#   'performance',
#   'better',
#   'performance',
#   'leads',
#   'conversions',
#   'end—that',
#   'for',
#   'here',
#   'checklist',
#   'performance',
#   'for',
#   'every',
#   'web',
#   'project',
#   'working',
#   'basic',
#   'gathering',
#   'from',
#   'will',
#   'help',
#   'later',
#   'performance',
#   'chapters',
#   'four',
#   'high',
#   'performance',
#   'mobile',
#   'web',
#   'provide',
#   'how',
#   'get',
#   'for',
#   'viewport',
#   '&',
#   'gt'],
#  ['paul',
#   'english’s',
#   'vision',
#   'pairing',
#   'ai',
#   'human',
#   'expertise',
#   'has',
#   'us',
#   'how',
#   'business',
#   'future.continue',
#   'reading',
#   'making',
#   'humans',
#   'cool',
#   'a',
#   'conversation',
#   'with',
#   'paul',
#   'english'],
#  ['matt',
#   'jorgensen',
#   'look',
#   'josephine',
#   'platform',
#   'connects',
#   'consumers',
#   'with',
#   'home',
#   'cooks.continue',
#   'reading',
#   'local',
#   'food',
#   'local',
#   'chefs'],
#  ['rana',
#   'foroohar',
#   'makers',
#   'takers',
#   'repercussions',
#   'reading',
#   'makers',
#   'a',
#   'conversation',
#   'with',
#   'rana',
#   'foroohar'],
#  ['the',
#   'behind',
#   'john',
#   'basset',
#   'iii',
#   'family',
#   'furniture',
#   'company',
#   'proves',
#   'good',
#   'jobs',
#   'not',
#   'continue',
#   'reading',
#   'factory',
#   'a',
#   'conversation',
#   'with',
#   'john',
#   'bassett',
#   'iii'],
#  ['at',
#   'next',
#   'economy',
#   '2016',
#   'business',
#   'leaders',
#   'policy',
#   'charted',
#   'course',
#   'from',
#   'economy',
#   'we',
#   'experience',
#   'economy',
#   'brings',
#   'prosperity',
#   'leaders',
#   'policy',
#   'came',
#   'san',
#   'francisco',
#   'for',
#   "o'reilly",
#   'next',
#   'economy',
#   'summit',
#   '2016',
#   'below',
#   'find',
#   'links',
#   'highlights',
#   'from',
#   'event',
#   'on-demand',
#   'for',
#   'blood',
#   'keller',
#   'rinaudo',
#   'company',
#   'zipline',
#   'using',
#   'with',
#   'poor',
#   'watch',
#   '``',
#   'on-demand',
#   'for',
#   'blood',
#   'a',
#   'conversation',
#   'with',
#   'jeff',
#   'weiner',
#   'linkedin',
#   'ceo',
#   'jeff',
#   'weiner',
#   'what',
#   'linkedin',
#   'can'],
#  ['innovation',
#   'economics',
#   'decentralized',
#   'prediction',
#   'markets',
#   'front-end',
#   'build',
#   'tools',
#   'cs',
#   'debates',
#   'innovation',
#   'through',
#   'holmstrom',
#   'lens',
#   '[',
#   'nobel',
#   'prize-winner',
#   ']',
#   'holmstrom’s',
#   'work',
#   'has',
#   'provided',
#   'with',
#   'great',
#   'understanding',
#   'why',
#   'looks',
#   'way',
#   'via',
#   'marginal',
#   'revolution',
#   'augur',
#   'prediction',
#   'making',
#   'sense',
#   'front-end',
#   'build',
#   'tools',
#   'build',
#   'install',
#   ';',
#   'the',
#   'first',
#   'question',
#   'when',
#   'confronting',
#   'new',
#   'build',
#   '“is',
#   'for',
#   'for',
#   '”',
#   'vigorous',
#   'public',
#   'debates',
#   'computer',
#   'science',
#   'the',
#   'purpose',
#   'post'],
#  ['why',
#   'new',
#   'factor',
#   'can',
#   'between',
#   'failure',
#   'cloud.in',
#   'beyond',
#   'twelve-factor',
#   'app',
#   'i',
#   'present',
#   'new',
#   'guidelines',
#   'builds',
#   'heroku’s',
#   '12',
#   'factors',
#   'reflects',
#   'best',
#   'practices',
#   'for',
#   'building',
#   'cloud-native',
#   'i',
#   'have',
#   'changed',
#   'priority',
#   'factors',
#   'concept',
#   '“api',
#   'first”',
#   'be',
#   'considerations',
#   'for',
#   'will',
#   'be',
#   'running',
#   'cloud',
#   'these',
#   'new',
#   '15-factor',
#   'guidelines',
#   'one',
#   'codebase',
#   'api',
#   'first',
#   'dependency',
#   'design',
#   'build',
#   'release',
#   'run',
#   'configuration',
#   'credentials',
#   'code',
#   'logs',
#   'disposability',
#   'backing',
#   'environment',
#   'parity'],
#  ['five',
#   'questions',
#   'for',
#   'laura',
#   'mather',
#   'insights',
#   'how',
#   'groupthink',
#   'heterogeneous',
#   'recently',
#   'with',
#   'laura',
#   'mather',
#   'founder',
#   'ceo',
#   'unitive',
#   'groupthink',
#   'how',
#   'hampers',
#   'quickly',
#   'better',
#   'problems',
#   'here',
#   'highlights',
#   'from',
#   '1',
#   'what',
#   '“groupthink',
#   'groupthink',
#   'great',
#   'example',
#   'how',
#   'best',
#   'can',
#   'really',
#   'go',
#   'essentially',
#   'when',
#   'group',
#   'focused',
#   'getting',
#   'criticize',
#   'each',
#   'i’m',
#   'we’ve',
#   'happen',
#   'we’re',
#   'group',
#   'people',
#   'who',
#   'either',
#   'very',
#   'loud',
#   'very',
#   'well',
#   'respected',
#   'comment',
#   'everyone',
#   'nodding',
#   'sometimes'],
#  ['douglas',
#   'rushkoff',
#   'way',
#   'forward',
#   'local',
#   'circular',
#   'economy',
#   'where',
#   'community',
#   'helps',
#   'us',
#   'build',
#   'human-centered',
#   'reading',
#   'throwing',
#   'rocks',
#   'google',
#   'bus',
#   'a',
#   'conversation',
#   'with',
#   'douglas',
#   'rushkoff'],
#  ['honor',
#   'using',
#   'real',
#   'vexing',
#   'problem',
#   'for',
#   'whose',
#   'loved',
#   'need',
#   'care.continue',
#   'reading',
#   'aging',
#   'with',
#   'honor',
#   'a',
#   'conversation',
#   'with',
#   'seth',
#   'sternberg',
#   'phaedra',
#   'ellis-lamkins'],
#  ['james',
#   'nord',
#   'fohr',
#   'card',
#   'us',
#   'how',
#   'reputation',
#   'gained',
#   'gets',
#   'converted',
#   'cash.continue',
#   'reading',
#   'making'],
#  ['graphs',
#   'from',
#   'max',
#   'roser’s',
#   'our',
#   'world',
#   'data',
#   'have',
#   'become',
#   'fixture',
#   'conversations',
#   'world',
#   'roser',
#   'reminds',
#   'us',
#   'we',
#   'play',
#   'cards',
#   'right',
#   'future',
#   'bright.continue',
#   'reading',
#   'our',
#   'world'],
#  ['linkedin',
#   'ceo',
#   'jeff',
#   'weiner',
#   'what',
#   'linkedin',
#   'us',
#   'how',
#   'we',
#   'can',
#   'better',
#   'key',
#   'reading',
#   'a',
#   'conversation',
#   'with',
#   'jeff',
#   'weiner'],
#  ['keller',
#   'rinaudo',
#   'company',
#   'zipline',
#   'using',
#   'with',
#   'poor',
#   'continue',
#   'reading',
#   'on-demand',
#   'for',
#   'blood'],
#  ['niantic',
#   'founder',
#   'ceo',
#   'john',
#   'hanke',
#   'his',
#   'creating',
#   'pokémon',
#   'go',
#   'what',
#   'us',
#   'future',
#   'entertainment.continue',
#   'reading',
#   'the',
#   'city',
#   'a',
#   'conversation',
#   'with',
#   'john',
#   'hanke',
#   'niantic',
#   'creator',
#   'pokémon',
#   'go'],
#  ['natalie',
#   'foster',
#   'aspen',
#   'institute',
#   'hosts',
#   'conversation',
#   'with',
#   'andy',
#   'stern',
#   'raising',
#   'floor',
#   'elizabeth',
#   'rhodes',
#   'who',
#   'heading',
#   'up',
#   'y',
#   'combinator’s',
#   'new',
#   'universal',
#   'basic',
#   'experiments',
#   'continue',
#   'reading',
#   'is',
#   'for',
#   'universal',
#   'basic']]

# %%
len(master_list[0]) ###checking the lenght of the list at position 0
# Out:
# 48

# %%
for s in master_list:    ###printing the content of all lists
    print(s)
# Out:
# ['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']
# ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']
# ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']
# ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']
# ['tim', 'frick', 'products', 'reading', 'how', 'for']
# ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']
# ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']
# ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us', 'for', 'building', 'svg', 'animations', 'new', "o'reilly", 'training', 'center', 'boston', 'nov.', '1-2']
# ['understand', 'how', 'capital', 'one', 'embraced', 'continuous', 'learn', 'core', 'principles', 'best', 'practices', 'behind', 'reading', 'part', 'pipeline', 'why', 'continuous', 'essential']
# ['in', 'video', 'brian', 'l.', 'gorman', 'uncovers', 'relationship', 'between', 'efficiency', 'branch', 'prediction', 'when', 'executing', 'java.continue', 'reading', 'does', 'run', 'faster', 'unsorted', 'java']
# ['a', 'common', 'java', 'pass', 'by', 'reference', 'language', 'in', 'video', 'brian', 'l.', 'gorman', 'exposes', 'workings', 'pass', 'by', 'value.continue', 'reading', 'is', 'java', 'pass', 'by', 'reference', 'pass', 'by', 'value']
# ['roberto', 'di', 'cosmo', 'reveals', 'behind', 'launch', 'software', 'heritage', 'project', 'has', '3', 'billion', 'unique', 'code', 'files', '650', 'unique', 'commits.continue', 'reading', 'why', 'how', 'software', 'heritage', 'building', 'universal']
# ['lauri', 'apple', 'zalando', 'how', 'company.continue', 'reading', 'building', 'culture', 'europe’s', 'largest', 'fashion', 'platform']
# ['open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'continue', 'reading', 'how', 'got', 'here']
# ['karen', 'sandler', 'freedom', 'underlies', 'effectively', 'problems', 'we', 'need', 'new', 'way', 'relation', 'justice', 'causes.continue', 'reading', 'is', 'freedom', 'justice']
# ['awesome', 'falsehoods', 'neural', 'network', 'vision', 'toy', 'family', 'robots', 'over-engineered', 'software', 'awesome', 'falsehoods', 'great', 'collections', 'lies', 'we', 'programmers', 'what', 'email', 'what', 'networks', 'favourite', 'zones', 'how', 'do', 'neural', 'networks', 'see', 'the', 'world', 'youtube', 'video', 'explainer', 'anki', 'cozmo', 'robot', 'compare', 'nxrobo', 'big-i', 'first', 'personalized', 'family', 'robot', 'big-i', 'natural-interaction', 'robot', 'with', '3d', 'vision', 'voice', 'programming', 'perception', 'it', 'can', 'needs', 'ten', 'modern', 'software', 'over-engineering', 'mistakes']
# ['lessons', 'learned', 'fastly', 'how', 'build', 'robust', 'contains', 'properly', 'communicates', 'prevent', 'recurrence.in', 'complex', 'failure', 'rule', 'and', 'failure', 'can', 'have', 'wide', 'ranging', 'especially', 'when', 'responsible', 'for', '1', 'per', 'internet', 'as', 'content', 'delivery', 'network', 'cdn', 'fastly', 'large', 'global', 'environment', 'which', 'faces', 'both', 'from', 'reliability', 'perspective', 'as', 'we', 'put', 'place', 'robust', 'would', 'us', 'rapidly', 'contain', 'would', 'ensure', 'communication', 'would', 'flow', 'effectively', 'both', 'within', 'company']
# ['the', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity', 'administrative', 'processes', 'port', 'binding', 'stateless', 'processes']
# ['5', 'questions', 'for', 'binu', 'ramakrishnan', 'insights', 'centralized', 'ci/cd', 'environments', 'common', 'protection', 'for', 'recently', 'with', 'binu', 'ramakrishnan', 'principal', 'engineer', 'yahoo', 'with', 'centralized', 'continuous', 'continuous', 'ci/cd', 'platform', 'protect', 'here', 'highlights', 'from', '1', 'how', 'can', 'ci/cd', 'platform', 'posture', 'lately', 'has', 'from', 'environments', 'favor', 'ci/cd', 'environments', 'a', 'factor', 'behind', 'platform', 'economies', 'in', 'build', 'environments', 'each', 'build', 'the', 'risk', 'exposure', 'from', 'limited', 'because', 'each', 'likely']
# ['kris', 'borchers', 'javascript.continue', 'reading', 'evolving', 'javascript', 'ecosystem']
# ['mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbor', 'web', 'cloud.continue', 'reading', 'brilliant', 'pebbles']
# ['danese', 'cooper', 'explores', 'innersource', 'within', 'walls', 'reading', 'how', 'innersource', 'like', 'flossing']
# ['watch', 'highlights', 'covering', 'business', 'from', 'oscon', 'london', '2016.people', 'from', 'community', 'came', 'for', 'oscon', 'london', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'brilliant', 'pebbles', 'mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbour', 'web', 'cloud', 'watch', '``', 'brilliant', 'pebbles', 'how', 'got', 'here', 'open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'watch']
# ['male', 'allies', 'learning', 'maps', 'machine', 'learning', 'biology', '``', 'the', 'attention', 'merchants', 'male', 'allies', 'bingo', 'card', 'via', 'anna', 'christison', 'so', 'you', 'want', 'learn', 'physics', 'really', 'learning', 'at', "o'reilly", 'we', 'been', 'hard', 'learning', 'paths', 'for', 'untargeted', 'metabolomics', 'using', 'deep', 'learning', 'this', 'untargeted', 'unbiased', 'every', 'change', 'cell', 'gives', 'us', 'for', 'biology', 'learning', 'has', 'been', 'key', 'getting', 'here', 'reliably', 'the', 'attention', 'merchants', 'the', 'epic']
# ['5', 'questions', 'for', 'timothy', 'gallo', 'allan', 'liska', 'insights', 'common', 'ransomware', 'how', 'find', 'balance', 'between', 'risks', 'productivity.i', 'recently', 'with', 'ransomware', 'co-authors', 'allan', 'liska', 'consulting', 'engineer', 'recorded', 'future', 'timothy', 'gallo', 'cyber', 'engineer', 'symantec', 'challenges', 'ransomware', 'how', 'here', 'highlights', 'from', '1', 'can', 'explain', 'common', 'for', 'ransomware', 'how', 'have', 'persisted', 'the', 'common', 'email', 'via', 'web', 'using', 'exploits', 'kits', 'there', 'have', 'been', 'ransomware', 'like', 'keranger']
# ['amazing', 'china', 'deep', 'learning', 'memory', 'vr', 'spaces', 'javascript', 'song', 'what', '$', '50', 'buys', 'you', 'at', 'huaqianbei', 'markets', 'shenzhen', 'was', 'blown', '$', '6', 'for', 'gsm', 'chipset', 'cpu', 'lcd', 'battery', 'pcb', 'housing', 'watch', 'band', 'microusb', 'cable', 'box', 'and', 'labor', 'differentiable', 'neural', 'computers', 'deepmind', 'latest', 'work', 'putting', 'learning', 'lets', 'computers', 'learn', 'form', 'navigate', 'complex', 'modalvr', 'nolan', 'bushnell', 'new', 'which', 'hopes', 'for', 'vr', 'what']
# ['this', 'free', 'webcast', 'provides', 'quick', 'lesson', 'updating', 'relational', 'oct.', '26', '2pm', 'pt.virtually', 'every', 'requires', 'persistent', 'one', 'best', 'features', 'spring', 'framework', 'how', 'easily', 'provides', 'work', 'with', 'relational', 'this', 'free', 'webcast', 'being', 'held', 'oct.', '26', '2pm', 'pt', 'will', 'how', 'use', 'spring', 'jdbctemplate', 'updating', 'relational', 'very', 'well', 'handling', 'exceptions', 'using', 'discussions', 'both', 'spring', 'jpa', 'working', 'with', 'nosql', 'will', 'be', 'no', 'previous', 'spring', 'experience']
# ['author', 'mark', 'richards', 'walks', '10', 'common', 'pitfalls', 'provides', 'for', 'preface', 'in', 'late', '2006', 'soa', 'was', 'craze', 'companies', 'were', 'jumping', 'bandwagon', 'embracing', 'soa', 'before', 'fully', 'understanding', 'very', 'complex', 'those', 'companies', 'embarked', 'soa', 'projects', 'found', 'constant', 'with', 'granularity', 'performance', 'particular', 'change', 'comes', 'with', 'soa', 'as', 'result', 'companies', 'either', 'soa', 'efforts', 'built', 'hybrid', 'not', 'fulfill', 'promises', 'soa', 'today', 'we', 'poised', 'repeat', 'experience', 'with']
# ['a', 'look', 'expanding', 'biotech', 'landscape', 'sxsw', 'south', 'by', 'southwest', 'sxsw', 'film', 'festival', 'happens', 'austin', 'texas', 'every', 'march', 'since', '1987', 'has', 'evolved', 'become', 'launching', 'pad', 'for', 'wide', 'range', 'figure', '1-1', 'figure', '1-1', 'the', 'sxsw', 'festival', 'phylogenetic', 'reflects', 'cultural', 'the', 'rumblings', 'biotech', 'wave', 'closer', 'look', 'evolving', 'programming', 'ecosystem', 'biotech', 'labs', 'labs', 'like', 'craig', 'venter', '23andme', 'ubiome', 'genspace', 'la', 'pailasse', 'ginkgo', 'bioworks', 'biobuilder']
# ['the', 'o’reilly', 'bots', 'podcast', 'bots', 'can', 'respond', 'groups', 'users.the', 'workplace', 'rich', 'venue', 'for', 'bots', 'help', 'with', 'productivity', 'collaboration', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'focus', 'workplace', 'bots', 'we', 'begin', 'by', 'with', 'jassim', 'latif', 'head', 'partnerships', 'slack', 'bots', 'written', 'by', 'for', 'human', 'resources', '“we’re', 'building', 'future', 'where', 'value', 'people', 'building', 'slack', 'far', 'value', 'slack', '”', 'latif', 'reading', 'jassim', 'latif']
# ['the', 'o’reilly', 'design', 'podcast', 'design', 'creating', 'right', 'environment.in', 'week’s', 'design', 'podcast', 'i', 'with', 'kristin', 'skinner', 'adaptive', 'path', 'head', 'capital', 'one', 'co-author', 'org', 'design', 'for', 'design', 'orgs', 'we', 'what', 'we', 'can', 'learn', 'from', 'golden', 'state', 'warriors.continue', 'reading', 'kristin', 'skinner']
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'natalino', 'busa', 'feature', 'engineering', 'predictive', 'episode', 'o’reilly', 'data', 'show', 'o’reilly’s', 'editor', 'jenn', 'webb', 'with', 'natalino', 'busa', 'predictive', 'challenges', 'feature', 'engineering', 'new', 'class', 'enabling', 'features', 'emerge', 'from', 'patterns', 'within', 'they', 'relationship', 'between', 'predictive', 'high-quality', 'how', 'learning', 'being', 'used', 'financial', 'reading', 'understanding', 'predictive']
# ['take', 'learning', 'followed', 'previous', 'post', 'learned', 'how', 'gpu-accelerated', 'tensorflow', 'create', 'classifier', 'linux', 'computer', 'honestly', 'process', 'classifying', 'consuming', 'laptop', 'have', 'want', 'classify', 'enter', 'lot', 'code', 'just', 'classify', 'thankfully', 'not', 'well', 'publicized', 'can', 'run', 'inception', 'classifier—or', 'classifier—live', 'camera-equipped', 'phone', 'you', 'need', 'point', 'camera', 'what', 'classify', 'tensorflow', 'will', 'what', 'you', 'can', 'use', 'tensorflow', 'raspberry', 'pi', 'but', 'for', 'i', 'will', 'be', 'using', 'android', 'i’ll']
# ['cake', 'cutting', 'tea', 'making', 'google', 'interviewing', 'automation', 'puzzling', 'fair', 'cake-cutting', 'but', 'april', 'computer', 'expectations', 'by', 'posting', 'paper', 'envy-free', 'cake-cutting', 'whose', 'running', 'number', 'players', 'not', 'preferences', '[', ']', 'the', 'extraordinarily', 'complex', 'cake', 'n', 'players', 'can', 'require', 'n^n^n^n^n^n', 'roughly', 'equivalent', 'number', 'cuts', 'even', 'for', 'just', 'handful', 'players', 'number', 'greater', 'number', 'universe', 'you', 'ca', "n't", 'have', 'cake', 'compute', 'english', 'man', 'spends', '11', 'hours']
# ['word', 'embedding', 'natural', 'language', 'processing.word', 'embedding', 'words', 'vectors', 'whose', 'relative', 'correlate', 'with', 'this', 'unsupervised', 'learning', 'natural', 'language', 'processing', 'nlp', 'encode', 'words', 'which', 'provide', 'no', 'useful', 'regarding', 'relationships', 'exist', 'between', 'words', 'word', 'embedding', 'nlp', 'whereby', 'words', 'phrases', 'from', 'vocabulary', 'vectors', 'real', 'numbers', 'low-dimensional', 'relative', 'vocabulary', 'between', 'vectors', 'correlate', 'with', 'words’', 'for', 'example', 'let’s', 'words', 'woman', 'queen', 'king', 'we', 'can', 'get', 'vector']
# ['insider', "o'reilly", 'security', 'conference', 'proposal', 'process', 'rejection', 'o’reilly', 'security', 'conference', 'we’ve', 'had', 'great', 'from', 'folks', 'especially', 'who', 'looking', 'forward', 'what', 'works', 'with', 'like-minded', 'professionals', 'we’ve', 'received', 'queries', 'process', 'for', 'handling', 'call', 'for', 'proposals', 'cfp', 'in', 'we’ll', 'be', 'quite', 'bit', 'event', 'we', 'want', 'present', 'feedback', 'from', 'cfp', 'process', 'bit', 'version', '“behind', 'music.”', 'tune', 'next', 'week', 'when', 'we’ll', 'follow', 'up', 'with', 'post']
# ['learn', 'how', 'capital', 'one', 'continuous', 'release', 'process', 'common', 'roadblocks.continue', 'reading', 'making', 'continuous', 'reality', 'large', 'enterprise']
# ['the', 'o’reilly', 'security', 'podcast', 'coarse-grained', 'embracing', 'ephemeral', 'empathy', 'for', 'everyone.in', 'episode', 'i', 'with', 'dan', 'kaminsky', 'founder', 'chief', 'white', 'ops', 'we', 'what', 'national', 'institutes', 'health', 'nih', 'for', 'would', 'look', 'like', 'pros', 'cons', 'docker', 'ephemeral', 'how', 'listening', 'people', 'better', 'can', 'for', 'everyone.continue', 'reading', 'dan', 'kaminsky', 'creating', 'nih', 'for']
# ['twitter', 'financially', 'vr', 'skeptically', 'electronica', 'originally', 'stack', 'overflow', 'competitively', 'twitter', 'buyout', 'financial', 'analysis', 'somewhere', 'near', 'half', 'billion', 'costs', 'need', 'be', 'and', 'firing', 'people', 'being', 'general', 'bastard', 'it', 'jack', 'dorsey', 'burning', 'half', 'billion', 'per', "n't", 'business', 'via', 'marginal', 'revolution', 'carmack', 'keynote', 'oculus', '3', '``', 'we', '[', 'vr', 'community', ']', 'coasting', 'novelty', 'wonder', 'being', 'people', 'have', 'never', 'before', 'he', 'continued', '``', 'but']
# ['this', 'report', 'explores', 'how', 'political', 'helps', 'everything', 'from', 'voter', 'contacts', 'prologue', 'the', 'role', 'data', 'campaigns', 'andrew', 'therriault', 'was', 'democratic', 'national', 'committee', 'director', 'data', 'science', 'from', '2014', '2016', 'leading', 'voter', 'used', 'by', 'democratic', 'campaigns', 'watching', 'news', 'coverage', '2016', 'presidential', 'race', 'easy', 'election', 'unlike', 'come', 'before', 'behind', 'campaigns', 'continuing', 'has', 'been', 'underway', 'for', 'modern', 'campaigns', 'us', 'have', 'become', 'reliant', 'with', 'each', 'election']
# ['this', 'chapter', 'from', 'lean', 'ux', '2nd', 'edition', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive', 'collaborative', 'process', 'agile', 'now', 'at', 'huge', 'products', 'like', 'amazon’s', 'kindle', 'apple’s', 'user', 'experience', 'ux', 'but', 'agile', 'work', 'with', 'ux', 'continues', 'be', 'challenge', 'for', 'companies', 'in', 'chapter', 'we', 'review', 'how', 'lean', 'ux', 'can', 'fit', 'within', 'popular', 'flavor', 'agile—scrum—and', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive']
# ['crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'encountered', 'patterns', 'passing', 'nutshell', 'general', 'can', 'use', 'crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'so', 'patterns', 'part', 'here', 'five', 'reasons', '1', 'make', 'life', 'easier', 'by', 'not', 'reinventing', 'wheel', 'there’s', 'constant', 'no', 'projects', 'will', 'late', 'budget', 'it’s', 'change', 'change', 'when', 'requirements', 'change', 'grow', 'new', 'features', 'when', 'performance', 'we’re']
# ['best', 'practices', 'for', 'web', 'web', 'web', 'not', 'paying', 'enough', 'websites’', 'performance', 'and', 'we', 'users', 'paying', 'for', 'it’s', 'for', 'website', 'creators', 'understand', 'what', 'harms', 'performance', 'what', 'performance', 'better', 'performance', 'leads', 'conversions', 'end—that', 'for', 'here', 'checklist', 'performance', 'for', 'every', 'web', 'project', 'working', 'basic', 'gathering', 'from', 'will', 'help', 'later', 'performance', 'chapters', 'four', 'high', 'performance', 'mobile', 'web', 'provide', 'how', 'get', 'for', 'viewport', '&', 'gt']
# ['paul', 'english’s', 'vision', 'pairing', 'ai', 'human', 'expertise', 'has', 'us', 'how', 'business', 'future.continue', 'reading', 'making', 'humans', 'cool', 'a', 'conversation', 'with', 'paul', 'english']
# ['matt', 'jorgensen', 'look', 'josephine', 'platform', 'connects', 'consumers', 'with', 'home', 'cooks.continue', 'reading', 'local', 'food', 'local', 'chefs']
# ['rana', 'foroohar', 'makers', 'takers', 'repercussions', 'reading', 'makers', 'a', 'conversation', 'with', 'rana', 'foroohar']
# ['the', 'behind', 'john', 'basset', 'iii', 'family', 'furniture', 'company', 'proves', 'good', 'jobs', 'not', 'continue', 'reading', 'factory', 'a', 'conversation', 'with', 'john', 'bassett', 'iii']
# ['at', 'next', 'economy', '2016', 'business', 'leaders', 'policy', 'charted', 'course', 'from', 'economy', 'we', 'experience', 'economy', 'brings', 'prosperity', 'leaders', 'policy', 'came', 'san', 'francisco', 'for', "o'reilly", 'next', 'economy', 'summit', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'on-demand', 'for', 'blood', 'keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'watch', '``', 'on-demand', 'for', 'blood', 'a', 'conversation', 'with', 'jeff', 'weiner', 'linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'can']
# ['innovation', 'economics', 'decentralized', 'prediction', 'markets', 'front-end', 'build', 'tools', 'cs', 'debates', 'innovation', 'through', 'holmstrom', 'lens', '[', 'nobel', 'prize-winner', ']', 'holmstrom’s', 'work', 'has', 'provided', 'with', 'great', 'understanding', 'why', 'looks', 'way', 'via', 'marginal', 'revolution', 'augur', 'prediction', 'making', 'sense', 'front-end', 'build', 'tools', 'build', 'install', ';', 'the', 'first', 'question', 'when', 'confronting', 'new', 'build', '“is', 'for', 'for', '”', 'vigorous', 'public', 'debates', 'computer', 'science', 'the', 'purpose', 'post']
# ['why', 'new', 'factor', 'can', 'between', 'failure', 'cloud.in', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity']
# ['five', 'questions', 'for', 'laura', 'mather', 'insights', 'how', 'groupthink', 'heterogeneous', 'recently', 'with', 'laura', 'mather', 'founder', 'ceo', 'unitive', 'groupthink', 'how', 'hampers', 'quickly', 'better', 'problems', 'here', 'highlights', 'from', '1', 'what', '“groupthink', 'groupthink', 'great', 'example', 'how', 'best', 'can', 'really', 'go', 'essentially', 'when', 'group', 'focused', 'getting', 'criticize', 'each', 'i’m', 'we’ve', 'happen', 'we’re', 'group', 'people', 'who', 'either', 'very', 'loud', 'very', 'well', 'respected', 'comment', 'everyone', 'nodding', 'sometimes']
# ['douglas', 'rushkoff', 'way', 'forward', 'local', 'circular', 'economy', 'where', 'community', 'helps', 'us', 'build', 'human-centered', 'reading', 'throwing', 'rocks', 'google', 'bus', 'a', 'conversation', 'with', 'douglas', 'rushkoff']
# ['honor', 'using', 'real', 'vexing', 'problem', 'for', 'whose', 'loved', 'need', 'care.continue', 'reading', 'aging', 'with', 'honor', 'a', 'conversation', 'with', 'seth', 'sternberg', 'phaedra', 'ellis-lamkins']
# ['james', 'nord', 'fohr', 'card', 'us', 'how', 'reputation', 'gained', 'gets', 'converted', 'cash.continue', 'reading', 'making']
# ['graphs', 'from', 'max', 'roser’s', 'our', 'world', 'data', 'have', 'become', 'fixture', 'conversations', 'world', 'roser', 'reminds', 'us', 'we', 'play', 'cards', 'right', 'future', 'bright.continue', 'reading', 'our', 'world']
# ['linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'us', 'how', 'we', 'can', 'better', 'key', 'reading', 'a', 'conversation', 'with', 'jeff', 'weiner']
# ['keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'continue', 'reading', 'on-demand', 'for', 'blood']
# ['niantic', 'founder', 'ceo', 'john', 'hanke', 'his', 'creating', 'pokémon', 'go', 'what', 'us', 'future', 'entertainment.continue', 'reading', 'the', 'city', 'a', 'conversation', 'with', 'john', 'hanke', 'niantic', 'creator', 'pokémon', 'go']
# ['natalie', 'foster', 'aspen', 'institute', 'hosts', 'conversation', 'with', 'andy', 'stern', 'raising', 'floor', 'elizabeth', 'rhodes', 'who', 'heading', 'up', 'y', 'combinator’s', 'new', 'universal', 'basic', 'experiments', 'continue', 'reading', 'is', 'for', 'universal', 'basic']

# %%
#writing the lists to local file "new_filename.txt" as each list is a line in our file by using
##writelines in python3 to iterate thru lists

with open('new_filename.txt', 'w') as f:
    f.writelines("%s\n" % l for l in master_list)

###############words from each blog are selected, 
#####################has been scheduled 60 words what represent the content/summary of the document###################

# %%
import numpy
from nltk.cluster import KMeansClusterer, GAAClusterer, cosine_distance
import nltk.corpus
import nltk.stem
stemmer_func = nltk.stem.snowball.SnowballStemmer("english").stem
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
def normalize_word(word):
    return stemmer_func(word.lower())

# %%
def get_words(titles):
    words = set()
    for title in job_titles:
        for word in title.split():
            words.add(normalize_word(word))
    return list(words)

# %%
def vectorspaced(title):
    title_components = [normalize_word(word) for word in title.split()]
    return numpy.array([
        word in title_components and not word in stop_words
        for word in words], numpy.short)

# %%
title_file = open("new_filename.txt", 'r')

# %%
job_titles = [line.strip() for line in title_file.readlines()]
words = get_words(job_titles)
words[0:10]
# Out:
# ["deep',",
#  "chief',",
#  "code',",
#  "home',",
#  "jeff',",
#  "branch',",
#  "['keller',",
#  "making',",
#  "heterogeneous',",
#  "as',"]

# %%
[vectorspaced(title) for title in job_titles if title]
# Out:
# [array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 1, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 1, 0, 0], dtype=int16),
#  array([0, 0, 1, ..., 0, 1, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([1, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 1], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 1, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 1, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 1, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 1, ..., 0, 1, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int16)]

# %%
len(job_titles)
# Out:
# 60

# %%
for title in job_titles:
    print(title)
# Out:
# ['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']
# ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']
# ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']
# ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']
# ['tim', 'frick', 'products', 'reading', 'how', 'for']
# ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']
# ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']
# ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us', 'for', 'building', 'svg', 'animations', 'new', "o'reilly", 'training', 'center', 'boston', 'nov.', '1-2']
# ['understand', 'how', 'capital', 'one', 'embraced', 'continuous', 'learn', 'core', 'principles', 'best', 'practices', 'behind', 'reading', 'part', 'pipeline', 'why', 'continuous', 'essential']
# ['in', 'video', 'brian', 'l.', 'gorman', 'uncovers', 'relationship', 'between', 'efficiency', 'branch', 'prediction', 'when', 'executing', 'java.continue', 'reading', 'does', 'run', 'faster', 'unsorted', 'java']
# ['a', 'common', 'java', 'pass', 'by', 'reference', 'language', 'in', 'video', 'brian', 'l.', 'gorman', 'exposes', 'workings', 'pass', 'by', 'value.continue', 'reading', 'is', 'java', 'pass', 'by', 'reference', 'pass', 'by', 'value']
# ['roberto', 'di', 'cosmo', 'reveals', 'behind', 'launch', 'software', 'heritage', 'project', 'has', '3', 'billion', 'unique', 'code', 'files', '650', 'unique', 'commits.continue', 'reading', 'why', 'how', 'software', 'heritage', 'building', 'universal']
# ['lauri', 'apple', 'zalando', 'how', 'company.continue', 'reading', 'building', 'culture', 'europe’s', 'largest', 'fashion', 'platform']
# ['open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'continue', 'reading', 'how', 'got', 'here']
# ['karen', 'sandler', 'freedom', 'underlies', 'effectively', 'problems', 'we', 'need', 'new', 'way', 'relation', 'justice', 'causes.continue', 'reading', 'is', 'freedom', 'justice']
# ['awesome', 'falsehoods', 'neural', 'network', 'vision', 'toy', 'family', 'robots', 'over-engineered', 'software', 'awesome', 'falsehoods', 'great', 'collections', 'lies', 'we', 'programmers', 'what', 'email', 'what', 'networks', 'favourite', 'zones', 'how', 'do', 'neural', 'networks', 'see', 'the', 'world', 'youtube', 'video', 'explainer', 'anki', 'cozmo', 'robot', 'compare', 'nxrobo', 'big-i', 'first', 'personalized', 'family', 'robot', 'big-i', 'natural-interaction', 'robot', 'with', '3d', 'vision', 'voice', 'programming', 'perception', 'it', 'can', 'needs', 'ten', 'modern', 'software', 'over-engineering', 'mistakes']
# ['lessons', 'learned', 'fastly', 'how', 'build', 'robust', 'contains', 'properly', 'communicates', 'prevent', 'recurrence.in', 'complex', 'failure', 'rule', 'and', 'failure', 'can', 'have', 'wide', 'ranging', 'especially', 'when', 'responsible', 'for', '1', 'per', 'internet', 'as', 'content', 'delivery', 'network', 'cdn', 'fastly', 'large', 'global', 'environment', 'which', 'faces', 'both', 'from', 'reliability', 'perspective', 'as', 'we', 'put', 'place', 'robust', 'would', 'us', 'rapidly', 'contain', 'would', 'ensure', 'communication', 'would', 'flow', 'effectively', 'both', 'within', 'company']
# ['the', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity', 'administrative', 'processes', 'port', 'binding', 'stateless', 'processes']
# ['5', 'questions', 'for', 'binu', 'ramakrishnan', 'insights', 'centralized', 'ci/cd', 'environments', 'common', 'protection', 'for', 'recently', 'with', 'binu', 'ramakrishnan', 'principal', 'engineer', 'yahoo', 'with', 'centralized', 'continuous', 'continuous', 'ci/cd', 'platform', 'protect', 'here', 'highlights', 'from', '1', 'how', 'can', 'ci/cd', 'platform', 'posture', 'lately', 'has', 'from', 'environments', 'favor', 'ci/cd', 'environments', 'a', 'factor', 'behind', 'platform', 'economies', 'in', 'build', 'environments', 'each', 'build', 'the', 'risk', 'exposure', 'from', 'limited', 'because', 'each', 'likely']
# ['kris', 'borchers', 'javascript.continue', 'reading', 'evolving', 'javascript', 'ecosystem']
# ['mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbor', 'web', 'cloud.continue', 'reading', 'brilliant', 'pebbles']
# ['danese', 'cooper', 'explores', 'innersource', 'within', 'walls', 'reading', 'how', 'innersource', 'like', 'flossing']
# ['watch', 'highlights', 'covering', 'business', 'from', 'oscon', 'london', '2016.people', 'from', 'community', 'came', 'for', 'oscon', 'london', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'brilliant', 'pebbles', 'mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbour', 'web', 'cloud', 'watch', '``', 'brilliant', 'pebbles', 'how', 'got', 'here', 'open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'watch']
# ['male', 'allies', 'learning', 'maps', 'machine', 'learning', 'biology', '``', 'the', 'attention', 'merchants', 'male', 'allies', 'bingo', 'card', 'via', 'anna', 'christison', 'so', 'you', 'want', 'learn', 'physics', 'really', 'learning', 'at', "o'reilly", 'we', 'been', 'hard', 'learning', 'paths', 'for', 'untargeted', 'metabolomics', 'using', 'deep', 'learning', 'this', 'untargeted', 'unbiased', 'every', 'change', 'cell', 'gives', 'us', 'for', 'biology', 'learning', 'has', 'been', 'key', 'getting', 'here', 'reliably', 'the', 'attention', 'merchants', 'the', 'epic']
# ['5', 'questions', 'for', 'timothy', 'gallo', 'allan', 'liska', 'insights', 'common', 'ransomware', 'how', 'find', 'balance', 'between', 'risks', 'productivity.i', 'recently', 'with', 'ransomware', 'co-authors', 'allan', 'liska', 'consulting', 'engineer', 'recorded', 'future', 'timothy', 'gallo', 'cyber', 'engineer', 'symantec', 'challenges', 'ransomware', 'how', 'here', 'highlights', 'from', '1', 'can', 'explain', 'common', 'for', 'ransomware', 'how', 'have', 'persisted', 'the', 'common', 'email', 'via', 'web', 'using', 'exploits', 'kits', 'there', 'have', 'been', 'ransomware', 'like', 'keranger']
# ['amazing', 'china', 'deep', 'learning', 'memory', 'vr', 'spaces', 'javascript', 'song', 'what', '$', '50', 'buys', 'you', 'at', 'huaqianbei', 'markets', 'shenzhen', 'was', 'blown', '$', '6', 'for', 'gsm', 'chipset', 'cpu', 'lcd', 'battery', 'pcb', 'housing', 'watch', 'band', 'microusb', 'cable', 'box', 'and', 'labor', 'differentiable', 'neural', 'computers', 'deepmind', 'latest', 'work', 'putting', 'learning', 'lets', 'computers', 'learn', 'form', 'navigate', 'complex', 'modalvr', 'nolan', 'bushnell', 'new', 'which', 'hopes', 'for', 'vr', 'what']
# ['this', 'free', 'webcast', 'provides', 'quick', 'lesson', 'updating', 'relational', 'oct.', '26', '2pm', 'pt.virtually', 'every', 'requires', 'persistent', 'one', 'best', 'features', 'spring', 'framework', 'how', 'easily', 'provides', 'work', 'with', 'relational', 'this', 'free', 'webcast', 'being', 'held', 'oct.', '26', '2pm', 'pt', 'will', 'how', 'use', 'spring', 'jdbctemplate', 'updating', 'relational', 'very', 'well', 'handling', 'exceptions', 'using', 'discussions', 'both', 'spring', 'jpa', 'working', 'with', 'nosql', 'will', 'be', 'no', 'previous', 'spring', 'experience']
# ['author', 'mark', 'richards', 'walks', '10', 'common', 'pitfalls', 'provides', 'for', 'preface', 'in', 'late', '2006', 'soa', 'was', 'craze', 'companies', 'were', 'jumping', 'bandwagon', 'embracing', 'soa', 'before', 'fully', 'understanding', 'very', 'complex', 'those', 'companies', 'embarked', 'soa', 'projects', 'found', 'constant', 'with', 'granularity', 'performance', 'particular', 'change', 'comes', 'with', 'soa', 'as', 'result', 'companies', 'either', 'soa', 'efforts', 'built', 'hybrid', 'not', 'fulfill', 'promises', 'soa', 'today', 'we', 'poised', 'repeat', 'experience', 'with']
# ['a', 'look', 'expanding', 'biotech', 'landscape', 'sxsw', 'south', 'by', 'southwest', 'sxsw', 'film', 'festival', 'happens', 'austin', 'texas', 'every', 'march', 'since', '1987', 'has', 'evolved', 'become', 'launching', 'pad', 'for', 'wide', 'range', 'figure', '1-1', 'figure', '1-1', 'the', 'sxsw', 'festival', 'phylogenetic', 'reflects', 'cultural', 'the', 'rumblings', 'biotech', 'wave', 'closer', 'look', 'evolving', 'programming', 'ecosystem', 'biotech', 'labs', 'labs', 'like', 'craig', 'venter', '23andme', 'ubiome', 'genspace', 'la', 'pailasse', 'ginkgo', 'bioworks', 'biobuilder']
# ['the', 'o’reilly', 'bots', 'podcast', 'bots', 'can', 'respond', 'groups', 'users.the', 'workplace', 'rich', 'venue', 'for', 'bots', 'help', 'with', 'productivity', 'collaboration', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'focus', 'workplace', 'bots', 'we', 'begin', 'by', 'with', 'jassim', 'latif', 'head', 'partnerships', 'slack', 'bots', 'written', 'by', 'for', 'human', 'resources', '“we’re', 'building', 'future', 'where', 'value', 'people', 'building', 'slack', 'far', 'value', 'slack', '”', 'latif', 'reading', 'jassim', 'latif']
# ['the', 'o’reilly', 'design', 'podcast', 'design', 'creating', 'right', 'environment.in', 'week’s', 'design', 'podcast', 'i', 'with', 'kristin', 'skinner', 'adaptive', 'path', 'head', 'capital', 'one', 'co-author', 'org', 'design', 'for', 'design', 'orgs', 'we', 'what', 'we', 'can', 'learn', 'from', 'golden', 'state', 'warriors.continue', 'reading', 'kristin', 'skinner']
# ['the', 'o’reilly', 'data', 'show', 'podcast', 'natalino', 'busa', 'feature', 'engineering', 'predictive', 'episode', 'o’reilly', 'data', 'show', 'o’reilly’s', 'editor', 'jenn', 'webb', 'with', 'natalino', 'busa', 'predictive', 'challenges', 'feature', 'engineering', 'new', 'class', 'enabling', 'features', 'emerge', 'from', 'patterns', 'within', 'they', 'relationship', 'between', 'predictive', 'high-quality', 'how', 'learning', 'being', 'used', 'financial', 'reading', 'understanding', 'predictive']
# ['take', 'learning', 'followed', 'previous', 'post', 'learned', 'how', 'gpu-accelerated', 'tensorflow', 'create', 'classifier', 'linux', 'computer', 'honestly', 'process', 'classifying', 'consuming', 'laptop', 'have', 'want', 'classify', 'enter', 'lot', 'code', 'just', 'classify', 'thankfully', 'not', 'well', 'publicized', 'can', 'run', 'inception', 'classifier—or', 'classifier—live', 'camera-equipped', 'phone', 'you', 'need', 'point', 'camera', 'what', 'classify', 'tensorflow', 'will', 'what', 'you', 'can', 'use', 'tensorflow', 'raspberry', 'pi', 'but', 'for', 'i', 'will', 'be', 'using', 'android', 'i’ll']
# ['cake', 'cutting', 'tea', 'making', 'google', 'interviewing', 'automation', 'puzzling', 'fair', 'cake-cutting', 'but', 'april', 'computer', 'expectations', 'by', 'posting', 'paper', 'envy-free', 'cake-cutting', 'whose', 'running', 'number', 'players', 'not', 'preferences', '[', ']', 'the', 'extraordinarily', 'complex', 'cake', 'n', 'players', 'can', 'require', 'n^n^n^n^n^n', 'roughly', 'equivalent', 'number', 'cuts', 'even', 'for', 'just', 'handful', 'players', 'number', 'greater', 'number', 'universe', 'you', 'ca', "n't", 'have', 'cake', 'compute', 'english', 'man', 'spends', '11', 'hours']
# ['word', 'embedding', 'natural', 'language', 'processing.word', 'embedding', 'words', 'vectors', 'whose', 'relative', 'correlate', 'with', 'this', 'unsupervised', 'learning', 'natural', 'language', 'processing', 'nlp', 'encode', 'words', 'which', 'provide', 'no', 'useful', 'regarding', 'relationships', 'exist', 'between', 'words', 'word', 'embedding', 'nlp', 'whereby', 'words', 'phrases', 'from', 'vocabulary', 'vectors', 'real', 'numbers', 'low-dimensional', 'relative', 'vocabulary', 'between', 'vectors', 'correlate', 'with', 'words’', 'for', 'example', 'let’s', 'words', 'woman', 'queen', 'king', 'we', 'can', 'get', 'vector']
# ['insider', "o'reilly", 'security', 'conference', 'proposal', 'process', 'rejection', 'o’reilly', 'security', 'conference', 'we’ve', 'had', 'great', 'from', 'folks', 'especially', 'who', 'looking', 'forward', 'what', 'works', 'with', 'like-minded', 'professionals', 'we’ve', 'received', 'queries', 'process', 'for', 'handling', 'call', 'for', 'proposals', 'cfp', 'in', 'we’ll', 'be', 'quite', 'bit', 'event', 'we', 'want', 'present', 'feedback', 'from', 'cfp', 'process', 'bit', 'version', '“behind', 'music.”', 'tune', 'next', 'week', 'when', 'we’ll', 'follow', 'up', 'with', 'post']
# ['learn', 'how', 'capital', 'one', 'continuous', 'release', 'process', 'common', 'roadblocks.continue', 'reading', 'making', 'continuous', 'reality', 'large', 'enterprise']
# ['the', 'o’reilly', 'security', 'podcast', 'coarse-grained', 'embracing', 'ephemeral', 'empathy', 'for', 'everyone.in', 'episode', 'i', 'with', 'dan', 'kaminsky', 'founder', 'chief', 'white', 'ops', 'we', 'what', 'national', 'institutes', 'health', 'nih', 'for', 'would', 'look', 'like', 'pros', 'cons', 'docker', 'ephemeral', 'how', 'listening', 'people', 'better', 'can', 'for', 'everyone.continue', 'reading', 'dan', 'kaminsky', 'creating', 'nih', 'for']
# ['twitter', 'financially', 'vr', 'skeptically', 'electronica', 'originally', 'stack', 'overflow', 'competitively', 'twitter', 'buyout', 'financial', 'analysis', 'somewhere', 'near', 'half', 'billion', 'costs', 'need', 'be', 'and', 'firing', 'people', 'being', 'general', 'bastard', 'it', 'jack', 'dorsey', 'burning', 'half', 'billion', 'per', "n't", 'business', 'via', 'marginal', 'revolution', 'carmack', 'keynote', 'oculus', '3', '``', 'we', '[', 'vr', 'community', ']', 'coasting', 'novelty', 'wonder', 'being', 'people', 'have', 'never', 'before', 'he', 'continued', '``', 'but']
# ['this', 'report', 'explores', 'how', 'political', 'helps', 'everything', 'from', 'voter', 'contacts', 'prologue', 'the', 'role', 'data', 'campaigns', 'andrew', 'therriault', 'was', 'democratic', 'national', 'committee', 'director', 'data', 'science', 'from', '2014', '2016', 'leading', 'voter', 'used', 'by', 'democratic', 'campaigns', 'watching', 'news', 'coverage', '2016', 'presidential', 'race', 'easy', 'election', 'unlike', 'come', 'before', 'behind', 'campaigns', 'continuing', 'has', 'been', 'underway', 'for', 'modern', 'campaigns', 'us', 'have', 'become', 'reliant', 'with', 'each', 'election']
# ['this', 'chapter', 'from', 'lean', 'ux', '2nd', 'edition', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive', 'collaborative', 'process', 'agile', 'now', 'at', 'huge', 'products', 'like', 'amazon’s', 'kindle', 'apple’s', 'user', 'experience', 'ux', 'but', 'agile', 'work', 'with', 'ux', 'continues', 'be', 'challenge', 'for', 'companies', 'in', 'chapter', 'we', 'review', 'how', 'lean', 'ux', 'can', 'fit', 'within', 'popular', 'flavor', 'agile—scrum—and', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive']
# ['crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'encountered', 'patterns', 'passing', 'nutshell', 'general', 'can', 'use', 'crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'so', 'patterns', 'part', 'here', 'five', 'reasons', '1', 'make', 'life', 'easier', 'by', 'not', 'reinventing', 'wheel', 'there’s', 'constant', 'no', 'projects', 'will', 'late', 'budget', 'it’s', 'change', 'change', 'when', 'requirements', 'change', 'grow', 'new', 'features', 'when', 'performance', 'we’re']
# ['best', 'practices', 'for', 'web', 'web', 'web', 'not', 'paying', 'enough', 'websites’', 'performance', 'and', 'we', 'users', 'paying', 'for', 'it’s', 'for', 'website', 'creators', 'understand', 'what', 'harms', 'performance', 'what', 'performance', 'better', 'performance', 'leads', 'conversions', 'end—that', 'for', 'here', 'checklist', 'performance', 'for', 'every', 'web', 'project', 'working', 'basic', 'gathering', 'from', 'will', 'help', 'later', 'performance', 'chapters', 'four', 'high', 'performance', 'mobile', 'web', 'provide', 'how', 'get', 'for', 'viewport', '&', 'gt']
# ['paul', 'english’s', 'vision', 'pairing', 'ai', 'human', 'expertise', 'has', 'us', 'how', 'business', 'future.continue', 'reading', 'making', 'humans', 'cool', 'a', 'conversation', 'with', 'paul', 'english']
# ['matt', 'jorgensen', 'look', 'josephine', 'platform', 'connects', 'consumers', 'with', 'home', 'cooks.continue', 'reading', 'local', 'food', 'local', 'chefs']
# ['rana', 'foroohar', 'makers', 'takers', 'repercussions', 'reading', 'makers', 'a', 'conversation', 'with', 'rana', 'foroohar']
# ['the', 'behind', 'john', 'basset', 'iii', 'family', 'furniture', 'company', 'proves', 'good', 'jobs', 'not', 'continue', 'reading', 'factory', 'a', 'conversation', 'with', 'john', 'bassett', 'iii']
# ['at', 'next', 'economy', '2016', 'business', 'leaders', 'policy', 'charted', 'course', 'from', 'economy', 'we', 'experience', 'economy', 'brings', 'prosperity', 'leaders', 'policy', 'came', 'san', 'francisco', 'for', "o'reilly", 'next', 'economy', 'summit', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'on-demand', 'for', 'blood', 'keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'watch', '``', 'on-demand', 'for', 'blood', 'a', 'conversation', 'with', 'jeff', 'weiner', 'linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'can']
# ['innovation', 'economics', 'decentralized', 'prediction', 'markets', 'front-end', 'build', 'tools', 'cs', 'debates', 'innovation', 'through', 'holmstrom', 'lens', '[', 'nobel', 'prize-winner', ']', 'holmstrom’s', 'work', 'has', 'provided', 'with', 'great', 'understanding', 'why', 'looks', 'way', 'via', 'marginal', 'revolution', 'augur', 'prediction', 'making', 'sense', 'front-end', 'build', 'tools', 'build', 'install', ';', 'the', 'first', 'question', 'when', 'confronting', 'new', 'build', '“is', 'for', 'for', '”', 'vigorous', 'public', 'debates', 'computer', 'science', 'the', 'purpose', 'post']
# ['why', 'new', 'factor', 'can', 'between', 'failure', 'cloud.in', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity']
# ['five', 'questions', 'for', 'laura', 'mather', 'insights', 'how', 'groupthink', 'heterogeneous', 'recently', 'with', 'laura', 'mather', 'founder', 'ceo', 'unitive', 'groupthink', 'how', 'hampers', 'quickly', 'better', 'problems', 'here', 'highlights', 'from', '1', 'what', '“groupthink', 'groupthink', 'great', 'example', 'how', 'best', 'can', 'really', 'go', 'essentially', 'when', 'group', 'focused', 'getting', 'criticize', 'each', 'i’m', 'we’ve', 'happen', 'we’re', 'group', 'people', 'who', 'either', 'very', 'loud', 'very', 'well', 'respected', 'comment', 'everyone', 'nodding', 'sometimes']
# ['douglas', 'rushkoff', 'way', 'forward', 'local', 'circular', 'economy', 'where', 'community', 'helps', 'us', 'build', 'human-centered', 'reading', 'throwing', 'rocks', 'google', 'bus', 'a', 'conversation', 'with', 'douglas', 'rushkoff']
# ['honor', 'using', 'real', 'vexing', 'problem', 'for', 'whose', 'loved', 'need', 'care.continue', 'reading', 'aging', 'with', 'honor', 'a', 'conversation', 'with', 'seth', 'sternberg', 'phaedra', 'ellis-lamkins']
# ['james', 'nord', 'fohr', 'card', 'us', 'how', 'reputation', 'gained', 'gets', 'converted', 'cash.continue', 'reading', 'making']
# ['graphs', 'from', 'max', 'roser’s', 'our', 'world', 'data', 'have', 'become', 'fixture', 'conversations', 'world', 'roser', 'reminds', 'us', 'we', 'play', 'cards', 'right', 'future', 'bright.continue', 'reading', 'our', 'world']
# ['linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'us', 'how', 'we', 'can', 'better', 'key', 'reading', 'a', 'conversation', 'with', 'jeff', 'weiner']
# ['keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'continue', 'reading', 'on-demand', 'for', 'blood']
# ['niantic', 'founder', 'ceo', 'john', 'hanke', 'his', 'creating', 'pokémon', 'go', 'what', 'us', 'future', 'entertainment.continue', 'reading', 'the', 'city', 'a', 'conversation', 'with', 'john', 'hanke', 'niantic', 'creator', 'pokémon', 'go']
# ['natalie', 'foster', 'aspen', 'institute', 'hosts', 'conversation', 'with', 'andy', 'stern', 'raising', 'floor', 'elizabeth', 'rhodes', 'who', 'heading', 'up', 'y', 'combinator’s', 'new', 'universal', 'basic', 'experiments', 'continue', 'reading', 'is', 'for', 'universal', 'basic']

# %%
cluster = KMeansClusterer(10, cosine_distance) ###cosine distance from nltk library
cluster.cluster([vectorspaced(title) for title in job_titles if title]) #vectorizing by building numpy array from the words
classified_examples = [cluster.classify(vectorspaced(title)) for title in job_titles]

# %%
for cluster_id, title in sorted(zip(classified_examples, job_titles)):
    print ("\n","Cluster number:",cluster_id, "\n", "Words extracted from the blog representing individual blog:", "\n", "\n",title)
# Out:
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['5', 'questions', 'for', 'binu', 'ramakrishnan', 'insights', 'centralized', 'ci/cd', 'environments', 'common', 'protection', 'for', 'recently', 'with', 'binu', 'ramakrishnan', 'principal', 'engineer', 'yahoo', 'with', 'centralized', 'continuous', 'continuous', 'ci/cd', 'platform', 'protect', 'here', 'highlights', 'from', '1', 'how', 'can', 'ci/cd', 'platform', 'posture', 'lately', 'has', 'from', 'environments', 'favor', 'ci/cd', 'environments', 'a', 'factor', 'behind', 'platform', 'economies', 'in', 'build', 'environments', 'each', 'build', 'the', 'risk', 'exposure', 'from', 'limited', 'because', 'each', 'likely']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['5', 'questions', 'for', 'timothy', 'gallo', 'allan', 'liska', 'insights', 'common', 'ransomware', 'how', 'find', 'balance', 'between', 'risks', 'productivity.i', 'recently', 'with', 'ransomware', 'co-authors', 'allan', 'liska', 'consulting', 'engineer', 'recorded', 'future', 'timothy', 'gallo', 'cyber', 'engineer', 'symantec', 'challenges', 'ransomware', 'how', 'here', 'highlights', 'from', '1', 'can', 'explain', 'common', 'for', 'ransomware', 'how', 'have', 'persisted', 'the', 'common', 'email', 'via', 'web', 'using', 'exploits', 'kits', 'there', 'have', 'been', 'ransomware', 'like', 'keranger']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['best', 'practices', 'for', 'web', 'web', 'web', 'not', 'paying', 'enough', 'websites’', 'performance', 'and', 'we', 'users', 'paying', 'for', 'it’s', 'for', 'website', 'creators', 'understand', 'what', 'harms', 'performance', 'what', 'performance', 'better', 'performance', 'leads', 'conversions', 'end—that', 'for', 'here', 'checklist', 'performance', 'for', 'every', 'web', 'project', 'working', 'basic', 'gathering', 'from', 'will', 'help', 'later', 'performance', 'chapters', 'four', 'high', 'performance', 'mobile', 'web', 'provide', 'how', 'get', 'for', 'viewport', '&', 'gt']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'encountered', 'patterns', 'passing', 'nutshell', 'general', 'can', 'use', 'crafted', 'by', 'experienced', 'practitioners', 'patterns', 'can', 'flexible', 'resilient', 'change', 'easier', 'so', 'patterns', 'part', 'here', 'five', 'reasons', '1', 'make', 'life', 'easier', 'by', 'not', 'reinventing', 'wheel', 'there’s', 'constant', 'no', 'projects', 'will', 'late', 'budget', 'it’s', 'change', 'change', 'when', 'requirements', 'change', 'grow', 'new', 'features', 'when', 'performance', 'we’re']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['five', 'questions', 'for', 'laura', 'mather', 'insights', 'how', 'groupthink', 'heterogeneous', 'recently', 'with', 'laura', 'mather', 'founder', 'ceo', 'unitive', 'groupthink', 'how', 'hampers', 'quickly', 'better', 'problems', 'here', 'highlights', 'from', '1', 'what', '“groupthink', 'groupthink', 'great', 'example', 'how', 'best', 'can', 'really', 'go', 'essentially', 'when', 'group', 'focused', 'getting', 'criticize', 'each', 'i’m', 'we’ve', 'happen', 'we’re', 'group', 'people', 'who', 'either', 'very', 'loud', 'very', 'well', 'respected', 'comment', 'everyone', 'nodding', 'sometimes']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['insider', "o'reilly", 'security', 'conference', 'proposal', 'process', 'rejection', 'o’reilly', 'security', 'conference', 'we’ve', 'had', 'great', 'from', 'folks', 'especially', 'who', 'looking', 'forward', 'what', 'works', 'with', 'like-minded', 'professionals', 'we’ve', 'received', 'queries', 'process', 'for', 'handling', 'call', 'for', 'proposals', 'cfp', 'in', 'we’ll', 'be', 'quite', 'bit', 'event', 'we', 'want', 'present', 'feedback', 'from', 'cfp', 'process', 'bit', 'version', '“behind', 'music.”', 'tune', 'next', 'week', 'when', 'we’ll', 'follow', 'up', 'with', 'post']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'security', 'podcast', 'coarse-grained', 'embracing', 'ephemeral', 'empathy', 'for', 'everyone.in', 'episode', 'i', 'with', 'dan', 'kaminsky', 'founder', 'chief', 'white', 'ops', 'we', 'what', 'national', 'institutes', 'health', 'nih', 'for', 'would', 'look', 'like', 'pros', 'cons', 'docker', 'ephemeral', 'how', 'listening', 'people', 'better', 'can', 'for', 'everyone.continue', 'reading', 'dan', 'kaminsky', 'creating', 'nih', 'for']
#
#  Cluster number: 0
#  Words extracted from the blog representing individual blog:
#
#  ['word', 'embedding', 'natural', 'language', 'processing.word', 'embedding', 'words', 'vectors', 'whose', 'relative', 'correlate', 'with', 'this', 'unsupervised', 'learning', 'natural', 'language', 'processing', 'nlp', 'encode', 'words', 'which', 'provide', 'no', 'useful', 'regarding', 'relationships', 'exist', 'between', 'words', 'word', 'embedding', 'nlp', 'whereby', 'words', 'phrases', 'from', 'vocabulary', 'vectors', 'real', 'numbers', 'low-dimensional', 'relative', 'vocabulary', 'between', 'vectors', 'correlate', 'with', 'words’', 'for', 'example', 'let’s', 'words', 'woman', 'queen', 'king', 'we', 'can', 'get', 'vector']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['danese', 'cooper', 'explores', 'innersource', 'within', 'walls', 'reading', 'how', 'innersource', 'like', 'flossing']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['lauri', 'apple', 'zalando', 'how', 'company.continue', 'reading', 'building', 'culture', 'europe’s', 'largest', 'fashion', 'platform']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['learn', 'how', 'capital', 'one', 'continuous', 'release', 'process', 'common', 'roadblocks.continue', 'reading', 'making', 'continuous', 'reality', 'large', 'enterprise']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['roberto', 'di', 'cosmo', 'reveals', 'behind', 'launch', 'software', 'heritage', 'project', 'has', '3', 'billion', 'unique', 'code', 'files', '650', 'unique', 'commits.continue', 'reading', 'why', 'how', 'software', 'heritage', 'building', 'universal']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['tim', 'frick', 'products', 'reading', 'how', 'for']
#
#  Cluster number: 1
#  Words extracted from the blog representing individual blog:
#
#  ['understand', 'how', 'capital', 'one', 'embraced', 'continuous', 'learn', 'core', 'principles', 'best', 'practices', 'behind', 'reading', 'part', 'pipeline', 'why', 'continuous', 'essential']
#
#  Cluster number: 2
#  Words extracted from the blog representing individual blog:
#
#  ['rana', 'foroohar', 'makers', 'takers', 'repercussions', 'reading', 'makers', 'a', 'conversation', 'with', 'rana', 'foroohar']
#
#  Cluster number: 2
#  Words extracted from the blog representing individual blog:
#
#  ['the', "o'reilly", 'radar', 'podcast', 'prediction', 'cognitive', 'biases', 'how', 'brains', 'come', 'week', 'episode', 'i', 'chat', 'with', 'sam', 'wang', 'professor', 'neuroscience', 'biology', 'princeton', 'wang', 'co-founder', 'princeton', 'election', 'consortium', 'focused', 'predicting', 'u.s.', 'national', 'elections', 'we', 'prediction', 'crazy', 'election', 'cycle', 'role', 'neuroscience', 'have', 'played', 'we', 'current', 'research', 'wang', 'his', 'working', 'u.s', 'brain', 'initiative', 'powerful', 'role', 'governments', 'play', 'research.continue', 'reading', 'sam', 'wang', 'predicting', 'election', 'finding']
#
#  Cluster number: 2
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'behind', 'john', 'basset', 'iii', 'family', 'furniture', 'company', 'proves', 'good', 'jobs', 'not', 'continue', 'reading', 'factory', 'a', 'conversation', 'with', 'john', 'bassett', 'iii']
#
#  Cluster number: 2
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'data', 'show', 'podcast', 'natalino', 'busa', 'feature', 'engineering', 'predictive', 'episode', 'o’reilly', 'data', 'show', 'o’reilly’s', 'editor', 'jenn', 'webb', 'with', 'natalino', 'busa', 'predictive', 'challenges', 'feature', 'engineering', 'new', 'class', 'enabling', 'features', 'emerge', 'from', 'patterns', 'within', 'they', 'relationship', 'between', 'predictive', 'high-quality', 'how', 'learning', 'being', 'used', 'financial', 'reading', 'understanding', 'predictive']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['amazing', 'china', 'deep', 'learning', 'memory', 'vr', 'spaces', 'javascript', 'song', 'what', '$', '50', 'buys', 'you', 'at', 'huaqianbei', 'markets', 'shenzhen', 'was', 'blown', '$', '6', 'for', 'gsm', 'chipset', 'cpu', 'lcd', 'battery', 'pcb', 'housing', 'watch', 'band', 'microusb', 'cable', 'box', 'and', 'labor', 'differentiable', 'neural', 'computers', 'deepmind', 'latest', 'work', 'putting', 'learning', 'lets', 'computers', 'learn', 'form', 'navigate', 'complex', 'modalvr', 'nolan', 'bushnell', 'new', 'which', 'hopes', 'for', 'vr', 'what']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['graphs', 'from', 'max', 'roser’s', 'our', 'world', 'data', 'have', 'become', 'fixture', 'conversations', 'world', 'roser', 'reminds', 'us', 'we', 'play', 'cards', 'right', 'future', 'bright.continue', 'reading', 'our', 'world']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['james', 'nord', 'fohr', 'card', 'us', 'how', 'reputation', 'gained', 'gets', 'converted', 'cash.continue', 'reading', 'making']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['karen', 'sandler', 'freedom', 'underlies', 'effectively', 'problems', 'we', 'need', 'new', 'way', 'relation', 'justice', 'causes.continue', 'reading', 'is', 'freedom', 'justice']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['lessons', 'learned', 'fastly', 'how', 'build', 'robust', 'contains', 'properly', 'communicates', 'prevent', 'recurrence.in', 'complex', 'failure', 'rule', 'and', 'failure', 'can', 'have', 'wide', 'ranging', 'especially', 'when', 'responsible', 'for', '1', 'per', 'internet', 'as', 'content', 'delivery', 'network', 'cdn', 'fastly', 'large', 'global', 'environment', 'which', 'faces', 'both', 'from', 'reliability', 'perspective', 'as', 'we', 'put', 'place', 'robust', 'would', 'us', 'rapidly', 'contain', 'would', 'ensure', 'communication', 'would', 'flow', 'effectively', 'both', 'within', 'company']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'continue', 'reading', 'how', 'got', 'here']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'bots', 'podcast', 'how', 'bots', 'way', 'companies', 'with', 'customers.customer', 'key', 'for', 'bots—one', 'first', 'we', 'when', 'we', 'world', 'full', 'ai-enabled', 'conversational', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'with', 'founders', 'companies', 'have', 'bots', 'help', 'consumers', 'companies', 'each', 'reading', 'michael', 'schneider', 'rachel', 'law', 'alyx', 'baldwin', 'customer', 'with', 'bots']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['this', 'report', 'explores', 'how', 'political', 'helps', 'everything', 'from', 'voter', 'contacts', 'prologue', 'the', 'role', 'data', 'campaigns', 'andrew', 'therriault', 'was', 'democratic', 'national', 'committee', 'director', 'data', 'science', 'from', '2014', '2016', 'leading', 'voter', 'used', 'by', 'democratic', 'campaigns', 'watching', 'news', 'coverage', '2016', 'presidential', 'race', 'easy', 'election', 'unlike', 'come', 'before', 'behind', 'campaigns', 'continuing', 'has', 'been', 'underway', 'for', 'modern', 'campaigns', 'us', 'have', 'become', 'reliant', 'with', 'each', 'election']
#
#  Cluster number: 3
#  Words extracted from the blog representing individual blog:
#
#  ['watch', 'highlights', 'covering', 'business', 'from', 'oscon', 'london', '2016.people', 'from', 'community', 'came', 'for', 'oscon', 'london', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'brilliant', 'pebbles', 'mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbour', 'web', 'cloud', 'watch', '``', 'brilliant', 'pebbles', 'how', 'got', 'here', 'open', 'licenses', 'have', 'us', 'well', 'for', 'but', 'cory', 'doctorow', 'need', 'help', 'we’re', 'going', 'era', 'which', 'computers', 'bodies', 'watch']
#
#  Cluster number: 4
#  Words extracted from the blog representing individual blog:
#
#  ['kid', 'privacy', 'chinese', 'creation', 'reality', 'rocks', 'chaos', 'monkey', '2', 'digital', 'defenders', 'free', 'cc-licensed', 'kids', 'booklet', 'privacy', 'via', 'cory', 'doctorow', 'news', 'ideas', 'are', "n't", 'intrinsically', 'valuable', 'executed', 'can', 'be', 'valuable', 'chinese', 'hardware', 'can', 'execute', 'faster', 'american', 'this', 'up', 'kickstarter', 'products', 'up', 'for', 'shenzhen', 'before', 'kickstarter', 'closes', 'via', 'boingboing', 'the', 'world', 'getting', 'better', 'nobody', 'knows', 'it', 'in', 'britain', '10', '%', 'people', 'world']
#
#  Cluster number: 4
#  Words extracted from the blog representing individual blog:
#
#  ['twitter', 'financially', 'vr', 'skeptically', 'electronica', 'originally', 'stack', 'overflow', 'competitively', 'twitter', 'buyout', 'financial', 'analysis', 'somewhere', 'near', 'half', 'billion', 'costs', 'need', 'be', 'and', 'firing', 'people', 'being', 'general', 'bastard', 'it', 'jack', 'dorsey', 'burning', 'half', 'billion', 'per', "n't", 'business', 'via', 'marginal', 'revolution', 'carmack', 'keynote', 'oculus', '3', '``', 'we', '[', 'vr', 'community', ']', 'coasting', 'novelty', 'wonder', 'being', 'people', 'have', 'never', 'before', 'he', 'continued', '``', 'but']
#
#  Cluster number: 5
#  Words extracted from the blog representing individual blog:
#
#  ['a', 'look', 'expanding', 'biotech', 'landscape', 'sxsw', 'south', 'by', 'southwest', 'sxsw', 'film', 'festival', 'happens', 'austin', 'texas', 'every', 'march', 'since', '1987', 'has', 'evolved', 'become', 'launching', 'pad', 'for', 'wide', 'range', 'figure', '1-1', 'figure', '1-1', 'the', 'sxsw', 'festival', 'phylogenetic', 'reflects', 'cultural', 'the', 'rumblings', 'biotech', 'wave', 'closer', 'look', 'evolving', 'programming', 'ecosystem', 'biotech', 'labs', 'labs', 'like', 'craig', 'venter', '23andme', 'ubiome', 'genspace', 'la', 'pailasse', 'ginkgo', 'bioworks', 'biobuilder']
#
#  Cluster number: 5
#  Words extracted from the blog representing individual blog:
#
#  ['cake', 'cutting', 'tea', 'making', 'google', 'interviewing', 'automation', 'puzzling', 'fair', 'cake-cutting', 'but', 'april', 'computer', 'expectations', 'by', 'posting', 'paper', 'envy-free', 'cake-cutting', 'whose', 'running', 'number', 'players', 'not', 'preferences', '[', ']', 'the', 'extraordinarily', 'complex', 'cake', 'n', 'players', 'can', 'require', 'n^n^n^n^n^n', 'roughly', 'equivalent', 'number', 'cuts', 'even', 'for', 'just', 'handful', 'players', 'number', 'greater', 'number', 'universe', 'you', 'ca', "n't", 'have', 'cake', 'compute', 'english', 'man', 'spends', '11', 'hours']
#
#  Cluster number: 5
#  Words extracted from the blog representing individual blog:
#
#  ['innovation', 'economics', 'decentralized', 'prediction', 'markets', 'front-end', 'build', 'tools', 'cs', 'debates', 'innovation', 'through', 'holmstrom', 'lens', '[', 'nobel', 'prize-winner', ']', 'holmstrom’s', 'work', 'has', 'provided', 'with', 'great', 'understanding', 'why', 'looks', 'way', 'via', 'marginal', 'revolution', 'augur', 'prediction', 'making', 'sense', 'front-end', 'build', 'tools', 'build', 'install', ';', 'the', 'first', 'question', 'when', 'confronting', 'new', 'build', '“is', 'for', 'for', '”', 'vigorous', 'public', 'debates', 'computer', 'science', 'the', 'purpose', 'post']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['if', 'we', 'let', 'put', 'us', 'work', 'will', 'be', 'because', 'failure', 'lack', 'will', 'better', 'future', 'full', 'video', 'from', 'tim', "o'reilly", 'white', 'house', 'frontiers', 'conference', 'i', 'had', 'honor', 'be', 'warmup', 'for', 'president', 'obama', 'white', 'house', 'frontiers', 'conference', 'carnegie', 'mellon', 'university', 'pittsburgh', 'here', 'prepared', 'from', 'i', 'as', 'watch', 'video', 'what', 'i', 'ended', 'up', 'exactly', 'what', 'i', 'had', 'written', 'but', 'reasonably', 'close', 'hearing', 'bob']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['learn', 'why', 'svg', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way.are', 'just', 'getting', 'svg', 'maybe', 'have', 'been', 'using', 'svgs', 'background', 'using', 'svgs', 'just', 'been', 'this', 'excerpt', 'from', 'upcoming', 'book', 'svg', 'animations', 'for', 'we', 'carefully', 'go', 'what', 'svg', 'why', 'from', 'css', 'work', 'common', 'hiccups', 'experience', 'way', 'if', 'learning', 'please', 'join', 'us', 'for', 'building', 'svg', 'animations', 'new', "o'reilly", 'training', 'center', 'boston', 'nov.', '1-2']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['male', 'allies', 'learning', 'maps', 'machine', 'learning', 'biology', '``', 'the', 'attention', 'merchants', 'male', 'allies', 'bingo', 'card', 'via', 'anna', 'christison', 'so', 'you', 'want', 'learn', 'physics', 'really', 'learning', 'at', "o'reilly", 'we', 'been', 'hard', 'learning', 'paths', 'for', 'untargeted', 'metabolomics', 'using', 'deep', 'learning', 'this', 'untargeted', 'unbiased', 'every', 'change', 'cell', 'gives', 'us', 'for', 'biology', 'learning', 'has', 'been', 'key', 'getting', 'here', 'reliably', 'the', 'attention', 'merchants', 'the', 'epic']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['take', 'learning', 'followed', 'previous', 'post', 'learned', 'how', 'gpu-accelerated', 'tensorflow', 'create', 'classifier', 'linux', 'computer', 'honestly', 'process', 'classifying', 'consuming', 'laptop', 'have', 'want', 'classify', 'enter', 'lot', 'code', 'just', 'classify', 'thankfully', 'not', 'well', 'publicized', 'can', 'run', 'inception', 'classifier—or', 'classifier—live', 'camera-equipped', 'phone', 'you', 'need', 'point', 'camera', 'what', 'classify', 'tensorflow', 'will', 'what', 'you', 'can', 'use', 'tensorflow', 'raspberry', 'pi', 'but', 'for', 'i', 'will', 'be', 'using', 'android', 'i’ll']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity', 'administrative', 'processes', 'port', 'binding', 'stateless', 'processes']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['this', 'chapter', 'from', 'lean', 'ux', '2nd', 'edition', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive', 'collaborative', 'process', 'agile', 'now', 'at', 'huge', 'products', 'like', 'amazon’s', 'kindle', 'apple’s', 'user', 'experience', 'ux', 'but', 'agile', 'work', 'with', 'ux', 'continues', 'be', 'challenge', 'for', 'companies', 'in', 'chapter', 'we', 'review', 'how', 'lean', 'ux', 'can', 'fit', 'within', 'popular', 'flavor', 'agile—scrum—and', 'how', 'blending', 'lean', 'ux', 'agile', 'can', 'create', 'productive']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['this', 'free', 'webcast', 'provides', 'quick', 'lesson', 'updating', 'relational', 'oct.', '26', '2pm', 'pt.virtually', 'every', 'requires', 'persistent', 'one', 'best', 'features', 'spring', 'framework', 'how', 'easily', 'provides', 'work', 'with', 'relational', 'this', 'free', 'webcast', 'being', 'held', 'oct.', '26', '2pm', 'pt', 'will', 'how', 'use', 'spring', 'jdbctemplate', 'updating', 'relational', 'very', 'well', 'handling', 'exceptions', 'using', 'discussions', 'both', 'spring', 'jpa', 'working', 'with', 'nosql', 'will', 'be', 'no', 'previous', 'spring', 'experience']
#
#  Cluster number: 6
#  Words extracted from the blog representing individual blog:
#
#  ['why', 'new', 'factor', 'can', 'between', 'failure', 'cloud.in', 'beyond', 'twelve-factor', 'app', 'i', 'present', 'new', 'guidelines', 'builds', 'heroku’s', '12', 'factors', 'reflects', 'best', 'practices', 'for', 'building', 'cloud-native', 'i', 'have', 'changed', 'priority', 'factors', 'concept', '“api', 'first”', 'be', 'considerations', 'for', 'will', 'be', 'running', 'cloud', 'these', 'new', '15-factor', 'guidelines', 'one', 'codebase', 'api', 'first', 'dependency', 'design', 'build', 'release', 'run', 'configuration', 'credentials', 'code', 'logs', 'disposability', 'backing', 'environment', 'parity']
#
#  Cluster number: 7
#  Words extracted from the blog representing individual blog:
#
#  ['awesome', 'falsehoods', 'neural', 'network', 'vision', 'toy', 'family', 'robots', 'over-engineered', 'software', 'awesome', 'falsehoods', 'great', 'collections', 'lies', 'we', 'programmers', 'what', 'email', 'what', 'networks', 'favourite', 'zones', 'how', 'do', 'neural', 'networks', 'see', 'the', 'world', 'youtube', 'video', 'explainer', 'anki', 'cozmo', 'robot', 'compare', 'nxrobo', 'big-i', 'first', 'personalized', 'family', 'robot', 'big-i', 'natural-interaction', 'robot', 'with', '3d', 'vision', 'voice', 'programming', 'perception', 'it', 'can', 'needs', 'ten', 'modern', 'software', 'over-engineering', 'mistakes']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['a', 'common', 'java', 'pass', 'by', 'reference', 'language', 'in', 'video', 'brian', 'l.', 'gorman', 'exposes', 'workings', 'pass', 'by', 'value.continue', 'reading', 'is', 'java', 'pass', 'by', 'reference', 'pass', 'by', 'value']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['at', 'next', 'economy', '2016', 'business', 'leaders', 'policy', 'charted', 'course', 'from', 'economy', 'we', 'experience', 'economy', 'brings', 'prosperity', 'leaders', 'policy', 'came', 'san', 'francisco', 'for', "o'reilly", 'next', 'economy', 'summit', '2016', 'below', 'find', 'links', 'highlights', 'from', 'event', 'on-demand', 'for', 'blood', 'keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'watch', '``', 'on-demand', 'for', 'blood', 'a', 'conversation', 'with', 'jeff', 'weiner', 'linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'can']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['author', 'mark', 'richards', 'walks', '10', 'common', 'pitfalls', 'provides', 'for', 'preface', 'in', 'late', '2006', 'soa', 'was', 'craze', 'companies', 'were', 'jumping', 'bandwagon', 'embracing', 'soa', 'before', 'fully', 'understanding', 'very', 'complex', 'those', 'companies', 'embarked', 'soa', 'projects', 'found', 'constant', 'with', 'granularity', 'performance', 'particular', 'change', 'comes', 'with', 'soa', 'as', 'result', 'companies', 'either', 'soa', 'efforts', 'built', 'hybrid', 'not', 'fulfill', 'promises', 'soa', 'today', 'we', 'poised', 'repeat', 'experience', 'with']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['honor', 'using', 'real', 'vexing', 'problem', 'for', 'whose', 'loved', 'need', 'care.continue', 'reading', 'aging', 'with', 'honor', 'a', 'conversation', 'with', 'seth', 'sternberg', 'phaedra', 'ellis-lamkins']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['in', 'video', 'brian', 'l.', 'gorman', 'uncovers', 'relationship', 'between', 'efficiency', 'branch', 'prediction', 'when', 'executing', 'java.continue', 'reading', 'does', 'run', 'faster', 'unsorted', 'java']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['keller', 'rinaudo', 'company', 'zipline', 'using', 'with', 'poor', 'continue', 'reading', 'on-demand', 'for', 'blood']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['kris', 'borchers', 'javascript.continue', 'reading', 'evolving', 'javascript', 'ecosystem']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['mark', 'shuttleworth', 'next', 'likely', 'come', 'from', 'laptop', 'pc', 'beating', 'neighbor', 'web', 'cloud.continue', 'reading', 'brilliant', 'pebbles']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['matt', 'jorgensen', 'look', 'josephine', 'platform', 'connects', 'consumers', 'with', 'home', 'cooks.continue', 'reading', 'local', 'food', 'local', 'chefs']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['natalie', 'foster', 'aspen', 'institute', 'hosts', 'conversation', 'with', 'andy', 'stern', 'raising', 'floor', 'elizabeth', 'rhodes', 'who', 'heading', 'up', 'y', 'combinator’s', 'new', 'universal', 'basic', 'experiments', 'continue', 'reading', 'is', 'for', 'universal', 'basic']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'bots', 'podcast', 'bots', 'can', 'respond', 'groups', 'users.the', 'workplace', 'rich', 'venue', 'for', 'bots', 'help', 'with', 'productivity', 'collaboration', 'in', 'episode', 'o’reilly', 'bots', 'podcast', 'pete', 'skomoroch', 'i', 'focus', 'workplace', 'bots', 'we', 'begin', 'by', 'with', 'jassim', 'latif', 'head', 'partnerships', 'slack', 'bots', 'written', 'by', 'for', 'human', 'resources', '“we’re', 'building', 'future', 'where', 'value', 'people', 'building', 'slack', 'far', 'value', 'slack', '”', 'latif', 'reading', 'jassim', 'latif']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'data', 'show', 'podcast', 'christopher', 'nguyen', 'early', 'apache', 'spark', 'learning', 'for', 'china', 'ai.in', 'episode', 'o’reilly', 'data', 'show', 'i', 'with', 'christopher', 'nguyen', 'ceo', 'co-founder', 'arimo', 'nguyen', 'arimo', 'were', 'first', 'proponents', 'apache', 'spark', 'alluxio', 'most', 'recently', 'arimo’s', 'products', 'has', 'relied', 'learning', 'range', 'business', 'problems.continue', 'reading', 'why', 'businesses', 'pay', 'learning']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['the', 'o’reilly', 'design', 'podcast', 'design', 'creating', 'right', 'environment.in', 'week’s', 'design', 'podcast', 'i', 'with', 'kristin', 'skinner', 'adaptive', 'path', 'head', 'capital', 'one', 'co-author', 'org', 'design', 'for', 'design', 'orgs', 'we', 'what', 'we', 'can', 'learn', 'from', 'golden', 'state', 'warriors.continue', 'reading', 'kristin', 'skinner']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['using', 'rum', 'http', 'vs.', 'https', 'world', 'regions', 'wireline', 'rural', 'wireline', 'wireless', 'isps.continue', 'reading', 'understanding', 'performance', 'penalty', 'http', 'vs.', 'https']
#
#  Cluster number: 8
#  Words extracted from the blog representing individual blog:
#
#  ['wan-replicated', 'data', 'nosql', 'modeling', 'sharing', 'roadmaps', 'shopping', 'statistics', 'bedrockdb', 'wan-replicated', 'foundation', 'for', 'global-scale', 'nosql', 'data', 'modeling', 'techniques', 'for', 'first', '2009', 'brave', 'new', 'data', 'world', 'roadmaps', 'views', 'product', 'road', 'for', 'good', '17', 'staggering', 'statistics', 'about', 'our', 'shopping', 'habits', '5', '50', '%', 'will', 'just', 'hit', 'free', '6', 'an', 'estimated', 'u.s.', 'gross', 'product', 'gdp', 'comes', 'from', 'retail', 'consumption', 'continue', 'reading', 'four', 'links', '19']
#
#  Cluster number: 9
#  Words extracted from the blog representing individual blog:
#
#  ['douglas', 'rushkoff', 'way', 'forward', 'local', 'circular', 'economy', 'where', 'community', 'helps', 'us', 'build', 'human-centered', 'reading', 'throwing', 'rocks', 'google', 'bus', 'a', 'conversation', 'with', 'douglas', 'rushkoff']
#
#  Cluster number: 9
#  Words extracted from the blog representing individual blog:
#
#  ['linkedin', 'ceo', 'jeff', 'weiner', 'what', 'linkedin', 'us', 'how', 'we', 'can', 'better', 'key', 'reading', 'a', 'conversation', 'with', 'jeff', 'weiner']
#
#  Cluster number: 9
#  Words extracted from the blog representing individual blog:
#
#  ['niantic', 'founder', 'ceo', 'john', 'hanke', 'his', 'creating', 'pokémon', 'go', 'what', 'us', 'future', 'entertainment.continue', 'reading', 'the', 'city', 'a', 'conversation', 'with', 'john', 'hanke', 'niantic', 'creator', 'pokémon', 'go']
#
#  Cluster number: 9
#  Words extracted from the blog representing individual blog:
#
#  ['paul', 'english’s', 'vision', 'pairing', 'ai', 'human', 'expertise', 'has', 'us', 'how', 'business', 'future.continue', 'reading', 'making', 'humans', 'cool', 'a', 'conversation', 'with', 'paul', 'english']
