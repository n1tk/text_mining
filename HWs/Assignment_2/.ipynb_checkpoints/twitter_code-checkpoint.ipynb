# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = "LUpqT9BUMzTzdDFVYMls5myJe"
CONSUMER_SECRET = "EP31NVKfAg1kWnE3CA0FRRARJMX07irWX9VQUNyUU2pnFPlBeg"
OAUTH_TOKEN = "41286065-O9xWYa1iTHxDEpc1aykOq61bDkOWQXo4CfCkp5W1F"
OAUTH_TOKEN_SECRET = "2zkghCKN8mxKVrAZmdAI8gmJgh8ZcfSKRh9NnAmqoAcku"

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x106ade4d0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2016-09-01T18:03:30Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D9%8A%D9%84%D9%86%D8%AF', u'query': u'%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D9%8A%D9%84%D9%86%D8%AF', u'tweet_volume': 80734, u'name': u'#\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647_\u062a\u0627\u064a\u0644\u0646\u062f', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23YouTubeIsOverParty', u'query': u'%23YouTubeIsOverParty', u'tweet_volume': 134353, u'name': u'#YouTubeIsOverParty', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%231SeptReclamoDeLibertad', u'query': u'%231SeptReclamoDeLibertad', u'tweet_volume': 385216, u'name': u'#1SeptReclamoDeLibertad', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%B4%D9%8A_%D8%AD%D9%84%D9%88_%D9%85%D9%86_3_%D8%A7%D8%AD%D8%B1%D9%81', u'query': u'%23%D8%B4%D9%8A_%D8%AD%D9%84%D9%88_%D9%85%D9%86_3_%D8%A7%D8%AD%D8%B1%D9%81', u'tweet_volume': 54574, u'name': u'#\u0634\u064a_\u062d\u0644\u0648_\u0645\u0646_3_\u0627\u062d\u0631\u0641', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23NoisS%C3%B3Queria', u'query': u'%23NoisS%C3%B3Queria', u'tweet_volume': 21872, u'name': u'#NoisS\xf3Queria', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%EC%B2%9C%EB%91%A5%EB%B2%88%EA%B0%9C', u'query': u'%EC%B2%9C%EB%91%A5%EB%B2%88%EA%B0%9C', u'tweet_volume': None, u'name': u'\ucc9c\ub465\ubc88\uac1c', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%EC%B2%9C%EB%91%A5%EC%86%8C%EB%A6%AC', u'query': u'%EC%B2%9C%EB%91%A5%EC%86%8C%EB%A6%AC', u'tweet_volume': None, u'name': u'\ucc9c\ub465\uc18c\ub9ac', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Rihanna+e+Drake%22', u'query': u'%22Rihanna+e+Drake%22', u'tweet_volume': 47377, u'name': u'Rihanna e Drake', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=STJD', u'query': u'STJD', u'tweet_volume': None, u'name': u'STJD', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22
u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22QB+Jerrod+Johnson%22', u'query': u'%22QB+Jerrod+Johnson%22', u'tweet_volume': None, u'name': u'QB Jerrod Johnson', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Descendant+of+the+Stars%22', u'query': u'%22Descendant+of+the+Stars%22', u'tweet_volume': None, u'name': u'Descendant of the Stars', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22D%27Andre+Swift%22', u'query': u'%22D%27Andre+Swift%22', u'tweet_volume': None, u'name': u"D'Andre Swift", u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Mario+Maker+3DS%22', u'query': u'%22Mario+Maker+3DS%22', u'tweet_volume': None, u'name': u'Mario Maker 3DS', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Thugz+Mansion%22', u'query': u'%22Thugz+Mansion%22', u'tweet_volume': None, u'name': u'Thugz Mansion', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Magnitude+7.1%22', u'query': u'%22Magnitude+7.1%22', u'tweet_volume': None, u'name': u'Magnitude 7.1', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22BEST+OF+THE+WORST%22', u'query': u'%22BEST+OF+THE+WORST%22', u'tweet_volume': None, u'name': u'BEST OF THE WORST', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Gears+of+War+4%22', u'query': u'%22Gears+of+War+4%22', u'tweet_volume': None, u'name': u'Gears of War 4', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Green+Suicide%22', u'query': u'%22Green+Suicide%22', u'tweet_volume': None, u'name': u'Green Suicide', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Big+Monday%22', u'query': u'%22Big+Monday%22', u'tweet_volume': None, u'name': u'Big Monday', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23WeirdMovieCredits', u'query': u'%23WeirdMovieCredits', u'tweet_volume': None, u'name': u'#WeirdMovieCredits', u'promoted_content': None}, {u'url':  ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2016-09-01T18:03:30Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D9%8A%D9%84%D9%86%D8%AF",
#     "query": "%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D8%AA%D8%A7%D9%8A%D9%84%D9%86%D8%AF",
#     "tweet_volume": 80734,
#     "name": "#\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647_\u062a\u0627\u064a\u0644\u0646\u062f",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23YouTubeIsOverParty",
#     "query": "%23YouTubeIsOverParty",
#     "tweet_volume": 134353,
#     "name": "#YouTubeIsOverParty",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%231SeptReclamoDeLibertad",
#     "query": "%231SeptReclamoDeLibertad",
#     "tweet_volume": 385216,
#     "name": "#1SeptReclamoDeLibertad",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B4%D9%8A_%D8%AD%D9%84%D9%88_%D9%85%D9%86_3_%D8%A7%D8%AD%D8%B1%D9%81",
#     "query": "%23%D8%B4%D9%8A_%D8%AD%D9%84%D9%88_%D9%85%D9%86_3_%D8%A7%D8%AD%D8%B1%D9%81",
#     "tweet_volume": 54574,
#     "name": "#\u0634\u064a_\u062d\u0644\u0648_\u0645\u0646_3_\u0627\u062d\u0631\u0641",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NoisS%C3%B3Queria",
#     "query": "%23NoisS%C3%B3Queria",
#     "tweet_volume": 21872,
#     "name": "#NoisS\u00f3Queria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%B2%9C%EB%91%A5%EB%B2%88%EA%B0%9C",
#     "query": "%EC%B2%9C%EB%91%A5%EB%B2%88%EA%B0%9C",
#     "tweet_volume": null,
#     "name": "\ucc9c\ub465\ubc88\uac1c",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%EC%B2%9C%EB%91%A5%EC%86%8C%EB%A6%AC",
#     "query": "%EC%B2%9C%EB%91%A5%EC%86%8C%EB%A6%AC",
#     "tweet_volume": null,
#     "name": "\ucc9c\ub465\uc18c\ub9ac",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Rihanna+e+Drake%22",
#     "query": "%22Rihanna+e+Drake%22",
#     "tweet_volume": 47377,
#     "name": "Rihanna e Drake",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=STJD",
#     "query": "STJD",
#     "tweet_volume": null,
#     "name": "STJD",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Francisco+de+Miranda%22",
#     "query": "%22Francisco+de+Miranda%22",
#     "tweet_volume": 57719,
#     "name": "Francisco de Miranda",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Nueva+Zelanda%22",
#     "query": "%22Nueva+Zelanda%22",
#     "tweet_volume": null,
#     "name": "Nueva Zelanda",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Osmanl%C4%B1+Partisi%22",
#     "query": "%22Osmanl%C4%B1+Partisi%22",
#     "tweet_volume": null,
#     "name": "Osmanl\u0131 Partisi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Anabella+de+Le%C3%B3n%22",
#     "query": "%22Anabella+de+Le%C3%B3n%22",
#     "tweet_volume": null,
#     "name": "Anabella de Le\u00f3n",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22GRACIAS+LEO+NARDINI%22",
#     "query": "%22GRACIAS+LEO+NARDINI%22",
#     "tweet_volume": 18551,
#     "name": "GRACIAS LEO NARDINI",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Las+Mercedes%22",
#     "query": "%22Las+Mercedes%22",
#     "tweet_volume": 20763,
#     "name": "Las Mercedes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Felipe+Massa%22",
#     "query": "%22Felipe+Massa%22",
#     "tweet_volume": 17975,
#     "name": "Felipe Massa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%EA%B1%B4%EA%B0%95%EC%83%81%EC%9D%98_%EC%95%BD%EC%A0%90%EC%9D%84_%EC%96%98%EA%B8%B0%ED%95%B4%EB%B3%B4%EC%9E%90",
#     "query": "%23%EA%B1%B4%EA%B0%95%EC%83%81%EC%9D%98_%EC%95%BD%EC%A0%90%EC%9D%84_%EC%96%98%EA%B8%B0%ED%95%B4%EB%B3%B4%EC%9E%90",
#     "tweet_volume": null,
#     "name": "#\uac74\uac15\uc0c1\uc758_\uc57d\uc810\uc744_\uc598\uae30\ud574\ubcf4\uc790",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%82%D8%B7%D8%B1_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86",
#     "query": "%23%D9%82%D8%B7%D8%B1_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86",
#     "tweet_volume": null,
#     "name": "#\u0642\u0637\u0631_\u0627\u064a\u0631\u0627\u0646",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23K%C4%B1saBirS%C3%B6zPayla%C5%9F",
#     "query": "%23K%C4%B1saBirS%C3%B6zPayla%C5%9F",
#     "tweet_volume": 27267,
#     "name": "#K\u0131saBirS\u00f6zPayla\u015f",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FelizJueves",
#     "query": "%23FelizJueves",
#     "tweet_volume": 53007,
#     "name": "#FelizJueves",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GalizaIsNotSpain",
#     "query": "%23GalizaIsNotSpain",
#     "tweet_volume": 21344,
#     "name": "#GalizaIsNotSpain",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MiMayorMiedo",
#     "query": "%23MiMayorMiedo",
#     "tweet_volume": null,
#     "name": "#MiMayorMiedo",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SpaceX",
#     "query": "%23SpaceX",
#     "tweet_volume": 19461,
#     "name": "#SpaceX",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%AD%D8%A8%D9%83_%D9%84%D8%A7%D9%86%D9%83",
#     "query": "%23%D8%A7%D8%AD%D8%A8%D9%83_%D9%84%D8%A7%D9%86%D9%83",
#     "tweet_volume": null,
#     "name": "#\u0627\u062d\u0628\u0643_\u0644\u0627\u0646\u0643",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 47581,
#     "name": "#ThursdayThoughts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MeEnsinaFelipeNeto",
#     "query": "%23MeEnsinaFelipeNeto",
#     "tweet_volume": null,
#     "name": "#MeEnsinaFelipeNeto",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SomosTodosGolpistas",
#     "query": "%23SomosTodosGolpistas",
#     "tweet_volume": 20927,
#     "name": "#SomosTodosGolpistas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%8A%D8%A7%D8%A8%D8%A7%D9%86_%D8%A7%D9%84%D8%A7%D9%85%D8%A7%D8%B1%D8%A7%D8%AA",
#     "query": "%23%D8%A7%D9%84%D9%8A%D8%A7%D8%A8%D8%A7%D9%86_%D8%A7%D9%84%D8%A7%D9%85%D8%A7%D8%B1%D8%A7%D8%AA",
#     "tweet_volume": 76585,
#     "name": "#\u0627\u0644\u064a\u0627\u0628\u0627\u0646_\u0627\u0644\u0627\u0645\u0627\u0631\u0627\u062a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SetembroDetremuraSDV",
#     "query": "%23SetembroDetremuraSDV",
#     "tweet_volume": 18307,
#     "name": "#SetembroDetremuraSDV",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Make2016Worse",
#     "query": "%23Make2016Worse",
#     "tweet_volume": null,
#     "name": "#Make2016Worse",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TipParaEnamorarA",
#     "query": "%23TipParaEnamorarA",
#     "tweet_volume": null,
#     "name": "#TipParaEnamorarA",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%C5%9EuYalanD%C3%BCnyada",
#     "query": "%23%C5%9EuYalanD%C3%BCnyada",
#     "tweet_volume": null,
#     "name": "#\u015euYalanD\u00fcnyada",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%82%D9%85%D9%87_%D9%88%D8%AF%D8%B9%D9%85_%D9%84%D9%84%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2",
#     "query": "%23%D8%A7%D9%84%D9%82%D9%85%D9%87_%D9%88%D8%AF%D8%B9%D9%85_%D9%84%D9%84%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2",
#     "tweet_volume": 93212,
#     "name": "#\u0627\u0644\u0642\u0645\u0647_\u0648\u062f\u0639\u0645_\u0644\u0644\u0641\u0648\u0644\u0648\u0631\u0632",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%AC%D9%87_%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D9%84%D9%85%D8%AA%D8%A7%D8%A8%D8%B9%D9%8A%D9%86%D9%83",
#     "query": "%23%D9%88%D8%AC%D9%87_%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D9%84%D9%85%D8%AA%D8%A7%D8%A8%D8%B9%D9%8A%D9%86%D9%83",
#     "tweet_volume": 19847,
#     "name": "#\u0648\u062c\u0647_\u0631\u0633\u0627\u0644\u0647_\u0644\u0645\u062a\u0627\u0628\u0639\u064a\u0646\u0643",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IfLifeWereLikeAHorrorFilm",
#     "query": "%23IfLifeWereLikeAHorrorFilm",
#     "tweet_volume": 11287,
#     "name": "#IfLifeWereLikeAHorrorFilm",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FaisParlerTaPP",
#     "query": "%23FaisParlerTaPP",
#     "tweet_volume": null,
#     "name": "#FaisParlerTaPP",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NintendoDirect",
#     "query": "%23NintendoDirect",
#     "tweet_volume": 32096,
#     "name": "#NintendoDirect",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HBDPawanKalyan",
#     "query": "%23HBDPawanKalyan",
#     "tweet_volume": 204122,
#     "name": "#HBDPawanKalyan",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8

#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%EC%9E%98%EC%83%9D%EA%B8%B4_%EA%B1%B8%EA%B7%B8%EB%A3%B9_%EB%8C%80%ED%9A%8C",
#     "query": "%23%EC%9E%98%EC%83%9D%EA%B8%B4_%EA%B1%B8%EA%B7%B8%EB%A3%B9_%EB%8C%80%ED%9A%8C",
#     "tweet_volume": null,
#     "name": "#\uc798\uc0dd\uae34_\uac78\uadf8\ub8f9_\ub300\ud68c",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23B%C3%BCy%C3%BCkUstaNTVde",
#     "query": "%23B%C3%BCy%C3%BCkUstaNTVde",
#     "tweet_volume": null,
#     "name": "#B\u00fcy\u00fckUstaNTVde",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23eqnz",
#     "query": "%23eqnz",
#     "tweet_volume": null,
#     "name": "#eqnz",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-09-01T18:05:37Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2016-09-01T17:58:29Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23YouTubeIsOverParty",
#     "query": "%23YouTubeIsOverParty",
#     "tweet_volume": 129976,
#     "name": "#YouTubeIsOverParty",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 47249,
#     "name": "#ThursdayThoughts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Make2016Worse",
#     "query": "%23Make2016Worse",
#     "tweet_volume": null,
#     "name": "#Make2016Worse",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IfLifeWereLikeAHorrorFilm",
#     "query": "%23IfLifeWereLikeAHorrorFilm",
#     "tweet_volume": 11119,
#     "name": "#IfLifeWereLikeAHorrorFilm",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SpaceX",
#     "query": "%23SpaceX",
#     "tweet_volume": 19105,
#     "name": "#SpaceX",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pumpkin+Spice+Latte%22",
#     "query": "%22Pumpkin+Spice+Latte%22",
#     "tweet_volume": 12113,
#     "name": "Pumpkin Spice Latte",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Georgetown+University%22",
#     "query": "%22Georgetown+University%22",
#     "tweet_volume": 14548,
#     "name": "Georgetown University",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Moulin+Rouge%22",
#     "query": "%22Moulin+Rouge%22",
#     "tweet_volume": null,
#     "name": "Moulin Rouge",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jackie+Chan%22",
#     "query": "%22Jackie+Chan%22",
#     "tweet_volume": null,
#     "name": "Jackie Chan",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Black+Lightning%22",
#     "query": "%22Black+Lightning%22",
#     "tweet_volume": null,
#     "name": "Black Lightning",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Greyson+Lambert%22",
#     "query": "%22Greyson+Lambert%22",
#     "tweet_volume": null,
#     "name": "Greyson Lambert",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22QB+Jerrod+Johnson%22",
#     "query": "%22QB+Jerrod+Johnson%22",
#     "tweet_volume": null,
#     "name": "QB Jerrod Johnson",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Descendant+of+the+Stars%22",
#     "query": "%22Descendant+of+the+Stars%22",
#     "tweet_volume": null,
#     "name": "Descendant of the Stars",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22D%27Andre+Swift%22",
#     "query": "%22D%27Andre+Swift%22",
#     "tweet_volume": null,
#     "name": "D'Andre Swift",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Mario+Maker+3DS%22",
#     "query": "%22Mario+Maker+3DS%22",
#     "tweet_volume": null,
#     "name": "Mario Maker 3DS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Thugz+Mansion%22",
#     "query": "%22Thugz+Mansion%22",
#     "tweet_volume": null,
#     "name": "Thugz Mansion",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Magnitude+7.1%22",
#     "query": "%22Magnitude+7.1%22",
#     "tweet_volume": null,
#     "name": "Magnitude 7.1",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22BEST+OF+THE+WORST%22",
#     "query": "%22BEST+OF+THE+WORST%22",
#     "tweet_volume": null,
#     "name": "BEST OF THE WORST",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Gears+of+War+4%22",
#     "query": "%22Gears+of+War+4%22",
#     "tweet_volume": null,
#     "name": "Gears of War 4",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Green+Suicide%22",
#     "query": "%22Green+Suicide%22",
#     "tweet_volume": null,
#     "name": "Green Suicide",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Big+Monday%22",
#     "query": "%22Big+Monday%22",
#     "tweet_volume": null,
#     "name": "Big Monday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WeirdMovieCredits",
#     "query": "%23WeirdMovieCredits",
#     "tweet_volume": null,
#     "name": "#WeirdMovieCredits",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%231SeptReclamoDeLibertad",
#     "query": "%231SeptReclamoDeLibertad",
#     "tweet_volume": 380436,
#     "name": "#1SeptReclamoDeLibertad",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BackToHogwarts",
#     "query": "%23BackToHogwarts",
#     "tweet_volume": 244086,
#     "name": "#BackToHogwarts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TomaDeCaracas",
#     "query": "%23TomaDeCaracas",
#     "tweet_volume": 217088,
#     "name": "#TomaDeCaracas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23helloseptember",
#     "query": "%23helloseptember",
#     "tweet_volume": null,
#     "name": "#helloseptember",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TropicalStormHermine",
#     "query": "%23TropicalStormHermine",
#     "tweet_volume": null,
#     "name": "#TropicalStormHermine",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PWI500",
#     "query": "%23PWI500",
#     "tweet_volume": null,
#     "name": "#PWI500",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PizzaHutHut",
#     "query": "%23PizzaHutHut",
#     "tweet_volume": null,
#     "name": "#PizzaHutHut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JacobBeOriginalParty",
#     "query": "%23JacobBeOriginalParty",
#     "tweet_volume": null,
#     "name": "#JacobBeOriginalParty",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NintendoDirect",
#     "query": "%23NintendoDirect",
#     "tweet_volume": 32011,
#     "name": "#NintendoDirect",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SLCC16",
#     "query": "%23SLCC16",
#     "tweet_volume": null,
#     "name": "#SLCC16",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HumanPartsTV",
#     "query": "%23HumanPartsTV",
#     "tweet_volume": null,
#     "name": "#HumanPartsTV",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23YR11K",
#     "query": "%23YR11K",
#     "tweet_volume": null,
#     "name": "#YR11K",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GameDay",
#     "query": "%23GameDay",
#     "tweet_volume": null,
#     "name": "#GameDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23901Day",
#     "query": "%23901Day",
#     "tweet_volume": null,
#     "name": "#901Day",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NFLDraft",
#     "query": "%23NFLDraft",
#     "tweet_volume": null,
#     "name": "#NFLDraft",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RestoreTheVRA",
#     "query": "%23RestoreTheVRA",
#     "tweet_volume": null,
#     "name": "#RestoreTheVRA",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23acmideast",
#     "query": "%23acmideast",
#     "tweet_volume": null,
#     "name": "#acmideast",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TwitterSmarter",
#     "query": "%23TwitterSmarter",
#     "tweet_volume": null,
#     "name": "#TwitterSmarter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23hurricanehermine",
#     "query": "%23hurricanehermine",
#     "tweet_volume": null,
#     "name": "#hurricanehermine",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappyBirthdayZendaya",
#     "query": "%23HappyBirthdayZendaya",
#     "tweet_volume": 11864,
#     "name": "#HappyBirthdayZendaya",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MTGChamp",
#     "query": "%23MTGChamp",
#     "tweet_volume": null,
#     "name": "#MTGChamp",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JAchat",
#     "query": "%23JAchat",
#     "tweet_volume": null,
#     "name": "#JAchat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AskALibrarian",
#     "query": "%23AskALibrarian",
#     "tweet_volume": null,
#     "name": "#AskALibrarian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UtahSolutionsSummit",
#     "query": "%23UtahSolutionsSummit",
#     "tweet_volume": null,
#     "name": "#UtahSolutionsSummit",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Sport24",
#     "query": "%23Sport24",
#     "tweet_volume": null,
#     "name": "#Sport24",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NCAAReform",
#     "query": "%23NCAAReform",
#     "tweet_volume": null,
#     "name": "#NCAAReform",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AllstonChristmas",
#     "query": "%23AllstonChristmas",
#     "tweet_volume": null,
#     "name": "#AllstonChristmas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LetMIAVote",
#     "query": "%23LetMIAVote",
#     "tweet_volume": null,
#     "name": "#LetMIAVote",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-09-01T18:05:37Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#1SeptReclamoDeLibertad', u'#SpaceX', u'#ThursdayThoughts', u'#Make2016Worse', u'#YouTubeIsOverParty', u'#NintendoDirect', u'#IfLifeWereLikeAHorrorFilm', u'#WeirdMovieCredits'])

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
from urllib import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MentionSomeoneImportantForYou' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-be47e063ff01> in <module>()
#      35
#      36 # Show one sample search result by slicing the list...
# ---> 37 print json.dumps(statuses[0], indent=1)
#
# IndexError: list index out of range

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print t['retweeted_status']

# Can you find the most retweeted tweet in your search results? Try do do it!

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
